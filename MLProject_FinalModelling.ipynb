# %% [markdown]
# #### Continuation from previous notebook
#
# Recall from second notebook: 'Find a base and add on new features'.
#
# Created a small set of new features in the third notebook.
#
# In the final (fourth) notebook, run models on the 'final' dataset.
#
# Run models:
#    1. Random Forest
#    2. Logistic Regression
#    3. SGD
#    4. GBC
#    5. AdaBoost Decision Tree.
#    6. Ensemble of ensembles (voting=soft).
#    7. Ensemble of 'best' (voting=soft).

# %%
## IMPORTS ##

# numpy and pandas for data manipulation
import numpy as np
import pandas as pd 

# sklearn preprocessing for dealing with categorical variables
from sklearn.preprocessing import LabelEncoder

# File system manangement
import os

# Suppress warnings 
import warnings
warnings.filterwarnings('ignore')

# matplotlib for plotting
import matplotlib.pyplot as plt

# garbage collector
import gc

# %%
# Load data fcn
def load_credit_data(data_path):
    csv_path = os.path.join("data", data_path)
    return pd.read_csv(csv_path)

# %%
# Load training data
# training_df = load_credit_data ("training_top.csv")
training_df = load_credit_data ("training_top_id.csv")
print (training_df.shape)
# Out:
# (307511, 268)

# %%
# Load features for training
features_training_df = load_credit_data ("training_new_features_v1.csv")
print (features_training_df.shape)
features_training_df.head()
# Out:
# (307511, 92)
#    SK_ID_CURR  APP_CREDIT_TO_ANNUITY_RATIO  APP_CREDIT_TO_GOODS_RATIO  \
# 0      100002                    16.461104                   1.158397
# 1      100003                    36.234085                   1.145199
# 2      100004                    20.000000                   1.000000
# 3      100006                    10.532818                   1.052803
# 4      100007                    23.461618                   1.000000
#
#    APP_INCOME_PER_CHLD  APP_CREDIT_TO_INCOME_RATIO  \
# 0             202500.0                    2.007889
# 1             270000.0                    4.790750
# 2              67500.0                    2.000000
# 3             135000.0                    2.316167
# 4             121500.0                    4.222222
#
#    APP_ANNUITY_TO_INCOME_RATIO  APP_SOURCES_PROD  APP_EXT_SOURCES_MEAN  \
# 0                     0.121977          0.003043              0.161787
# 1                     0.132216          0.119932              0.466757
# 2                     0.099999          0.119932              0.642739
# 3                     0.219898          0.119932              0.650442
# 4                     0.179961          0.119932              0.322738
#
#    APP_EXT_SCORES_STD  APP_CAR_TO_BIRTH_RATIO  \
# 0            0.092026               -0.000627
# 1            0.219895               -0.000627
# 2            0.122792               -0.001365
# 3            0.136021               -0.000627
# 4            0.136021               -0.000627
#
#                         ...                         \
# 0                       ...
# 1                       ...
# 2                       ...
# 3                       ...
# 4                       ...
#
#    INSTALL_DAYS_ENTRY_PAYMENT_MEDIAN  INSTALL_DAYS_INSTALMENT_MAX  \
# 0                             -312.0                        -25.0
# 1                             -806.0                       -536.0
# 2                             -763.0                       -724.0
# 3                             -211.0                        -11.0
# 4                             -852.5                        -14.0
#
#    INSTALL_DAYS_INSTALMENT_MIN  INSTALL_DAYS_INSTALMENT_MEDIAN  \
# 0                       -565.0                          -295.0
# 1                      -2310.0                          -797.0
# 2                       -784.0                          -754.0
# 3                       -545.0                          -206.0
# 4                      -2326.0                          -851.0
#
#    INSTALL_INSTPAY_PAY_TO_INSTALL_RATIO_MAX  \
# 0                                       1.0
# 1                                       1.0
# 2                                       1.0
# 3                                       1.0
# 4                                       1.0
#
#    INSTALL_INSTPAY_PAY_TO_INSTALL_RATIO_MIN  \
# 0                                   1.00000
# 1                                   1.00000
# 2                                   1.00000
# 3                                   1.00000
# 4                                   0.00005
#
#    INSTALL_INSTPAY_PAY_TO_INSTALL_RATIO_MEAN  \
# 0                                   1.000000
# 1                                   1.000000
# 2                                   1.000000
# 3                                   1.000000
# 4                                   0.954545
#
#    INSTALL_INSTPAY_DIFF_DAYS_INSTALL_DAYS_PAY_MAX  \
# 0                                            31.0
# 1                                            14.0
# 2                                            11.0
# 3                                            77.0
# 4                                            31.0
#
#    INSTALL_INSTPAY_DIFF_DAYS_INSTALL_DAYS_PAY_MIN  \
# 0                                            12.0
# 1                                             1.0
# 2                                             3.0
# 3                                             1.0
# 4                                           -12.0
#
#    INSTALL_INSTPAY_DIFF_DAYS_INSTALL_DAYS_PAY_MEAN
# 0                                        20.421053
# 1                                         7.160000
# 2                                         7.666667
# 3                                        19.375000
# 4                                         3.636364
#
# [5 rows x 92 columns]

# %%
# Merge for full set
# training_df = pd.concat ([training_df, features_training_df], axis=1)
training_df_merged = training_df.merge(right=features_training_df, on = 'SK_ID_CURR', how = 'left')

print (training_df_merged.shape)
training_df_merged.head()
# Out:
# (307511, 359)
#    SK_ID_CURR  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0      100002             0          202500.0    406597.5      24700.5
# 1      100003             0          270000.0   1293502.5      35698.5
# 2      100004             0           67500.0    135000.0       6750.0
# 3      100006             0          135000.0    312682.5      29686.5
# 4      100007             0          121500.0    513000.0      21865.5
#
#    REGION_POPULATION_RELATIVE  DAYS_BIRTH  DAYS_EMPLOYED  DAYS_REGISTRATION  \
# 0                    0.018801       -9461           -637            -3648.0
# 1                    0.003541      -16765          -1188            -1186.0
# 2                    0.010032      -19046           -225            -4260.0
# 3                    0.008019      -19005          -3039            -9833.0
# 4                    0.028663      -19932          -3038            -4311.0
#
#    DAYS_ID_PUBLISH                       ...                         \
# 0            -2120                       ...
# 1             -291                       ...
# 2            -2531                       ...
# 3            -2437                       ...
# 4            -3458                       ...
#
#    INSTALL_DAYS_ENTRY_PAYMENT_MEDIAN  INSTALL_DAYS_INSTALMENT_MAX  \
# 0                             -312.0                        -25.0
# 1                             -806.0                       -536.0
# 2                             -763.0                       -724.0
# 3                             -211.0                        -11.0
# 4                             -852.5                        -14.0
#
#    INSTALL_DAYS_INSTALMENT_MIN  INSTALL_DAYS_INSTALMENT_MEDIAN  \
# 0                       -565.0                          -295.0
# 1                      -2310.0                          -797.0
# 2                       -784.0                          -754.0
# 3                       -545.0                          -206.0
# 4                      -2326.0                          -851.0
#
#    INSTALL_INSTPAY_PAY_TO_INSTALL_RATIO_MAX  \
# 0                                       1.0
# 1                                       1.0
# 2                                       1.0
# 3                                       1.0
# 4                                       1.0
#
#    INSTALL_INSTPAY_PAY_TO_INSTALL_RATIO_MIN  \
# 0                                   1.00000
# 1                                   1.00000
# 2                                   1.00000
# 3                                   1.00000
# 4                                   0.00005
#
#    INSTALL_INSTPAY_PAY_TO_INSTALL_RATIO_MEAN  \
# 0                                   1.000000
# 1                                   1.000000
# 2                                   1.000000
# 3                                   1.000000
# 4                                   0.954545
#
#    INSTALL_INSTPAY_DIFF_DAYS_INSTALL_DAYS_PAY_MAX  \
# 0                                            31.0
# 1                                            14.0
# 2                                            11.0
# 3                                            77.0
# 4                                            31.0
#
#    INSTALL_INSTPAY_DIFF_DAYS_INSTALL_DAYS_PAY_MIN  \
# 0                                            12.0
# 1                                             1.0
# 2                                             3.0
# 3                                             1.0
# 4                                           -12.0
#
#    INSTALL_INSTPAY_DIFF_DAYS_INSTALL_DAYS_PAY_MEAN
# 0                                        20.421053
# 1                                         7.160000
# 2                                         7.666667
# 3                                        19.375000
# 4                                         3.636364
#
# [5 rows x 359 columns]

# %%
# Load testing data
testing_df = load_credit_data ("testing_top_id.csv")
print (testing_df.shape)
# Out:
# (48744, 268)

# %%
# Load features for testing
features_testing_df = load_credit_data ("testing_new_features_v1.csv")
print (features_testing_df.shape)
features_testing_df.head()
# Out:
# (48744, 92)
#    SK_ID_CURR  APP_CREDIT_TO_ANNUITY_RATIO  APP_CREDIT_TO_GOODS_RATIO  \
# 0      100001                    27.664697                     1.2640
# 1      100005                    12.824870                     1.2376
# 2      100013                     9.505482                     1.0528
# 3      100028                    32.130726                     1.0000
# 4      100038                    19.506034                     1.0000
#
#    APP_INCOME_PER_CHLD  APP_CREDIT_TO_INCOME_RATIO  \
# 0             135000.0                    4.213333
# 1              99000.0                    2.250182
# 2             202500.0                    3.275378
# 3             105000.0                    5.000000
# 4              90000.0                    3.475000
#
#    APP_ANNUITY_TO_INCOME_RATIO  APP_SOURCES_PROD  APP_EXT_SOURCES_MEAN  \
# 0                     0.152299          0.094803              0.567263
# 1                     0.175453          0.071345              0.429869
# 2                     0.344576          0.119686              0.655389
# 3                     0.155614          0.164177              0.549372
# 4                     0.178149          0.119686              0.313916
#
#    APP_EXT_SCORES_STD  APP_CAR_TO_BIRTH_RATIO  \
# 0            0.353601               -0.000624
# 1            0.136694               -0.000624
# 2            0.062788               -0.000250
# 3            0.055432               -0.000624
# 4            0.158068               -0.001227
#
#                         ...                         \
# 0                       ...
# 1                       ...
# 2                       ...
# 3                       ...
# 4                       ...
#
#    INSTALL_DAYS_ENTRY_PAYMENT_MEDIAN  INSTALL_DAYS_INSTALMENT_MAX  \
# 0                            -1715.0                      -1619.0
# 1                             -585.0                       -466.0
# 2                            -1383.0                        -14.0
# 3                             -812.0                        -27.0
# 4                             -634.0                       -457.0
#
#    INSTALL_DAYS_INSTALMENT_MIN  INSTALL_DAYS_INSTALMENT_MEDIAN  \
# 0                      -2916.0                         -1709.0
# 1                       -706.0                          -586.0
# 2                      -2705.0                         -1383.0
# 3                      -1773.0                          -812.0
# 4                       -787.0                          -622.0
#
#    INSTALL_INSTPAY_PAY_TO_INSTALL_RATIO_MAX  \
# 0                                       1.0
# 1                                       1.0
# 2                                       1.0
# 3                                       1.0
# 4                                       1.0
#
#    INSTALL_INSTPAY_PAY_TO_INSTALL_RATIO_MIN  \
# 0                                  1.000000
# 1                                  1.000000
# 2                                  0.000266
# 3                                  0.030496
# 4                                  1.000000
#
#    INSTALL_INSTPAY_PAY_TO_INSTALL_RATIO_MEAN  \
# 0                                   1.000000
# 1                                   1.000000
# 2                                   0.935484
# 3                                   0.911504
# 4                                   1.000000
#
#    INSTALL_INSTPAY_DIFF_DAYS_INSTALL_DAYS_PAY_MAX  \
# 0                                            36.0
# 1                                            37.0
# 2                                            38.0
# 3                                            19.0
# 4                                            18.0
#
#    INSTALL_INSTPAY_DIFF_DAYS_INSTALL_DAYS_PAY_MIN  \
# 0                                           -11.0
# 1                                            -1.0
# 2                                           -21.0
# 3                                            -7.0
# 4                                             9.0
#
#    INSTALL_INSTPAY_DIFF_DAYS_INSTALL_DAYS_PAY_MEAN
# 0                                         7.285714
# 1                                        23.555556
# 2                                         5.180645
# 3                                         3.000000
# 4                                        12.250000
#
# [5 rows x 92 columns]

# %%
# Merge for full set
# testing_df = pd.concat ([testing_df, features_testing_df], axis=1)
testing_df_merged = testing_df.merge(right=features_testing_df, on = 'SK_ID_CURR', how = 'left')

print (testing_df_merged.shape)
testing_df_merged.head()
# Out:
# (48744, 359)
#    SK_ID_CURR  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0      100001             0          135000.0    568800.0      20560.5
# 1      100005             0           99000.0    222768.0      17370.0
# 2      100013             0          202500.0    663264.0      69777.0
# 3      100028             2          315000.0   1575000.0      49018.5
# 4      100038             1          180000.0    625500.0      32067.0
#
#    REGION_POPULATION_RELATIVE  DAYS_BIRTH  DAYS_EMPLOYED  DAYS_REGISTRATION  \
# 0                    0.018850      -19241          -2329            -5170.0
# 1                    0.035792      -18064          -4469            -9118.0
# 2                    0.019101      -20038          -4458            -2175.0
# 3                    0.026392      -13976          -1866            -2000.0
# 4                    0.010032      -13040          -2191            -4000.0
#
#    DAYS_ID_PUBLISH                       ...                         \
# 0             -812                       ...
# 1            -1623                       ...
# 2            -3503                       ...
# 3            -4208                       ...
# 4            -4262                       ...
#
#    INSTALL_DAYS_ENTRY_PAYMENT_MEDIAN  INSTALL_DAYS_INSTALMENT_MAX  \
# 0                            -1715.0                      -1619.0
# 1                             -585.0                       -466.0
# 2                            -1383.0                        -14.0
# 3                             -812.0                        -27.0
# 4                             -634.0                       -457.0
#
#    INSTALL_DAYS_INSTALMENT_MIN  INSTALL_DAYS_INSTALMENT_MEDIAN  \
# 0                      -2916.0                         -1709.0
# 1                       -706.0                          -586.0
# 2                      -2705.0                         -1383.0
# 3                      -1773.0                          -812.0
# 4                       -787.0                          -622.0
#
#    INSTALL_INSTPAY_PAY_TO_INSTALL_RATIO_MAX  \
# 0                                       1.0
# 1                                       1.0
# 2                                       1.0
# 3                                       1.0
# 4                                       1.0
#
#    INSTALL_INSTPAY_PAY_TO_INSTALL_RATIO_MIN  \
# 0                                  1.000000
# 1                                  1.000000
# 2                                  0.000266
# 3                                  0.030496
# 4                                  1.000000
#
#    INSTALL_INSTPAY_PAY_TO_INSTALL_RATIO_MEAN  \
# 0                                   1.000000
# 1                                   1.000000
# 2                                   0.935484
# 3                                   0.911504
# 4                                   1.000000
#
#    INSTALL_INSTPAY_DIFF_DAYS_INSTALL_DAYS_PAY_MAX  \
# 0                                            36.0
# 1                                            37.0
# 2                                            38.0
# 3                                            19.0
# 4                                            18.0
#
#    INSTALL_INSTPAY_DIFF_DAYS_INSTALL_DAYS_PAY_MIN  \
# 0                                           -11.0
# 1                                            -1.0
# 2                                           -21.0
# 3                                            -7.0
# 4                                             9.0
#
#    INSTALL_INSTPAY_DIFF_DAYS_INSTALL_DAYS_PAY_MEAN
# 0                                         7.285714
# 1                                        23.555556
# 2                                         5.180645
# 3                                         3.000000
# 4                                        12.250000
#
# [5 rows x 359 columns]

# %%
# Drop ID
training_df = training_df_merged.drop ('SK_ID_CURR', axis=1)
testing_df = testing_df_merged.drop ('SK_ID_CURR', axis=1)

# %%
training_df.head()
# Out:
#    CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0             0          202500.0    406597.5      24700.5
# 1             0          270000.0   1293502.5      35698.5
# 2             0           67500.0    135000.0       6750.0
# 3             0          135000.0    312682.5      29686.5
# 4             0          121500.0    513000.0      21865.5
#
#    REGION_POPULATION_RELATIVE  DAYS_BIRTH  DAYS_EMPLOYED  DAYS_REGISTRATION  \
# 0                    0.018801       -9461           -637            -3648.0
# 1                    0.003541      -16765          -1188            -1186.0
# 2                    0.010032      -19046           -225            -4260.0
# 3                    0.008019      -19005          -3039            -9833.0
# 4                    0.028663      -19932          -3038            -4311.0
#
#    DAYS_ID_PUBLISH  OWN_CAR_AGE  \
# 0            -2120          9.0
# 1             -291          9.0
# 2            -2531         26.0
# 3            -2437          9.0
# 4            -3458          9.0
#
#                         ...                         \
# 0                       ...
# 1                       ...
# 2                       ...
# 3                       ...
# 4                       ...
#
#    INSTALL_DAYS_ENTRY_PAYMENT_MEDIAN  INSTALL_DAYS_INSTALMENT_MAX  \
# 0                             -312.0                        -25.0
# 1                             -806.0                       -536.0
# 2                             -763.0                       -724.0
# 3                             -211.0                        -11.0
# 4                             -852.5                        -14.0
#
#    INSTALL_DAYS_INSTALMENT_MIN  INSTALL_DAYS_INSTALMENT_MEDIAN  \
# 0                       -565.0                          -295.0
# 1                      -2310.0                          -797.0
# 2                       -784.0                          -754.0
# 3                       -545.0                          -206.0
# 4                      -2326.0                          -851.0
#
#    INSTALL_INSTPAY_PAY_TO_INSTALL_RATIO_MAX  \
# 0                                       1.0
# 1                                       1.0
# 2                                       1.0
# 3                                       1.0
# 4                                       1.0
#
#    INSTALL_INSTPAY_PAY_TO_INSTALL_RATIO_MIN  \
# 0                                   1.00000
# 1                                   1.00000
# 2                                   1.00000
# 3                                   1.00000
# 4                                   0.00005
#
#    INSTALL_INSTPAY_PAY_TO_INSTALL_RATIO_MEAN  \
# 0                                   1.000000
# 1                                   1.000000
# 2                                   1.000000
# 3                                   1.000000
# 4                                   0.954545
#
#    INSTALL_INSTPAY_DIFF_DAYS_INSTALL_DAYS_PAY_MAX  \
# 0                                            31.0
# 1                                            14.0
# 2                                            11.0
# 3                                            77.0
# 4                                            31.0
#
#    INSTALL_INSTPAY_DIFF_DAYS_INSTALL_DAYS_PAY_MIN  \
# 0                                            12.0
# 1                                             1.0
# 2                                             3.0
# 3                                             1.0
# 4                                           -12.0
#
#    INSTALL_INSTPAY_DIFF_DAYS_INSTALL_DAYS_PAY_MEAN
# 0                                        20.421053
# 1                                         7.160000
# 2                                         7.666667
# 3                                        19.375000
# 4                                         3.636364
#
# [5 rows x 358 columns]

# %%
testing_df.head()
# Out:
#    CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0             0          135000.0    568800.0      20560.5
# 1             0           99000.0    222768.0      17370.0
# 2             0          202500.0    663264.0      69777.0
# 3             2          315000.0   1575000.0      49018.5
# 4             1          180000.0    625500.0      32067.0
#
#    REGION_POPULATION_RELATIVE  DAYS_BIRTH  DAYS_EMPLOYED  DAYS_REGISTRATION  \
# 0                    0.018850      -19241          -2329            -5170.0
# 1                    0.035792      -18064          -4469            -9118.0
# 2                    0.019101      -20038          -4458            -2175.0
# 3                    0.026392      -13976          -1866            -2000.0
# 4                    0.010032      -13040          -2191            -4000.0
#
#    DAYS_ID_PUBLISH  OWN_CAR_AGE  \
# 0             -812          9.0
# 1            -1623          9.0
# 2            -3503          5.0
# 3            -4208          9.0
# 4            -4262         16.0
#
#                         ...                         \
# 0                       ...
# 1                       ...
# 2                       ...
# 3                       ...
# 4                       ...
#
#    INSTALL_DAYS_ENTRY_PAYMENT_MEDIAN  INSTALL_DAYS_INSTALMENT_MAX  \
# 0                            -1715.0                      -1619.0
# 1                             -585.0                       -466.0
# 2                            -1383.0                        -14.0
# 3                             -812.0                        -27.0
# 4                             -634.0                       -457.0
#
#    INSTALL_DAYS_INSTALMENT_MIN  INSTALL_DAYS_INSTALMENT_MEDIAN  \
# 0                      -2916.0                         -1709.0
# 1                       -706.0                          -586.0
# 2                      -2705.0                         -1383.0
# 3                      -1773.0                          -812.0
# 4                       -787.0                          -622.0
#
#    INSTALL_INSTPAY_PAY_TO_INSTALL_RATIO_MAX  \
# 0                                       1.0
# 1                                       1.0
# 2                                       1.0
# 3                                       1.0
# 4                                       1.0
#
#    INSTALL_INSTPAY_PAY_TO_INSTALL_RATIO_MIN  \
# 0                                  1.000000
# 1                                  1.000000
# 2                                  0.000266
# 3                                  0.030496
# 4                                  1.000000
#
#    INSTALL_INSTPAY_PAY_TO_INSTALL_RATIO_MEAN  \
# 0                                   1.000000
# 1                                   1.000000
# 2                                   0.935484
# 3                                   0.911504
# 4                                   1.000000
#
#    INSTALL_INSTPAY_DIFF_DAYS_INSTALL_DAYS_PAY_MAX  \
# 0                                            36.0
# 1                                            37.0
# 2                                            38.0
# 3                                            19.0
# 4                                            18.0
#
#    INSTALL_INSTPAY_DIFF_DAYS_INSTALL_DAYS_PAY_MIN  \
# 0                                           -11.0
# 1                                            -1.0
# 2                                           -21.0
# 3                                            -7.0
# 4                                             9.0
#
#    INSTALL_INSTPAY_DIFF_DAYS_INSTALL_DAYS_PAY_MEAN
# 0                                         7.285714
# 1                                        23.555556
# 2                                         5.180645
# 3                                         3.000000
# 4                                        12.250000
#
# [5 rows x 358 columns]

# %%
# Load labels data
labels_df = load_credit_data ("y_labels.csv")
print (labels_df.shape)

y_train = labels_df['TARGET'].copy()
# Out:
# (307511, 1)

# %%
# ROC curve
from sklearn.metrics import roc_curve, auc

def plot_roc_curve(fpr, tpr, label=None):
    plt.plot(fpr, tpr, linewidth=2, label=label)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.axis([0, 1, 0, 1])
    plt.xlabel('False Positive Rate', fontsize=16)
    plt.ylabel('True Positive Rate', fontsize=16)

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

final_rf = RandomForestClassifier(random_state=123)

param_grid = {'n_estimators': [20, 250, 300], 'max_depth' : [1, 3, 5]}
grid_search_final_rf = GridSearchCV(estimator=final_rf, param_grid=param_grid , cv=5, scoring='roc_auc', verbose=100)

grid_search_final_rf.fit(training_df, y_train)

# Results of the grid search for best n_estimator
print(grid_search_final_rf.best_params_)
print ("------------")

# Results of the grid search in general
cvres = grid_search_final_rf.cv_results_
for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]):
    print(mean_score, params)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] max_depth=1, n_estimators=20 ....................................
# [CV]  max_depth=1, n_estimators=20, score=0.7154802300884572, total=   4.7s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    5.9s remaining:    0.0s
# [CV] max_depth=1, n_estimators=20 ....................................
# [CV]  max_depth=1, n_estimators=20, score=0.7137236029392369, total=   4.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:   11.1s remaining:    0.0s
# [CV] max_depth=1, n_estimators=20 ....................................
# [CV]  max_depth=1, n_estimators=20, score=0.7115496698763748, total=   4.6s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:   17.1s remaining:    0.0s
# [CV] max_depth=1, n_estimators=20 ....................................
# [CV]  max_depth=1, n_estimators=20, score=0.7145898342361188, total=   4.3s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:   22.7s remaining:    0.0s
# [CV] max_depth=1, n_estimators=20 ....................................
# [CV]  max_depth=1, n_estimators=20, score=0.7124519281645377, total=   4.1s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:   28.0s remaining:    0.0s
# [CV] max_depth=1, n_estimators=250 ...................................
# [CV]  max_depth=1, n_estimators=250, score=0.7242310610582401, total=  34.3s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:  1.1min remaining:    0.0s
# [CV] max_depth=1, n_estimators=250 ...................................
# [CV]  max_depth=1, n_estimators=250, score=0.7229571252263556, total=  34.8s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:  1.7min remaining:    0.0s
# [CV] max_depth=1, n_estimators=250 ...................................
# [CV]  max_depth=1, n_estimators=250, score=0.7174714110790675, total=  33.7s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:  2.3min remaining:    0.0s
# [CV] max_depth=1, n_estimators=250 ...................................
# [CV]  max_depth=1, n_estimators=250, score=0.7290592543189418, total=  33.6s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:  2.9min remaining:    0.0s
# [CV] max_depth=1, n_estimators=250 ...................................
# [CV]  max_depth=1, n_estimators=250, score=0.7244159743458468, total=  35.5s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:  3.6min remaining:    0.0s
# [CV] max_depth=1, n_estimators=300 ...................................
# [CV]  max_depth=1, n_estimators=300, score=0.7256295144934917, total=  39.7s
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed:  4.3min remaining:    0.0s
# [CV] max_depth=1, n_estimators=300 ...................................
# [CV]  max_depth=1, n_estimators=300, score=0.7244033935765688, total=  40.1s
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:  5.0min remaining:    0.0s
# [CV] max_depth=1, n_estimators=300 ...................................
# [CV]  max_depth=1, n_estimators=300, score=0.7182843624707191, total=  39.9s
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed:  5.8min remaining:    0.0s
# [CV] max_depth=1, n_estimators=300 ...................................
# [CV]  max_depth=1, n_estimators=300, score=0.7297137713788693, total=  38.4s
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed:  6.5min remaining:    0.0s
# [CV] max_depth=1, n_estimators=300 ...................................
# [CV]  max_depth=1, n_estimators=300, score=0.7251388475719658, total=  38.8s
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:  7.2min remaining:    0.0s
# [CV] max_depth=3, n_estimators=20 ....................................
# [CV]  max_depth=3, n_estimators=20, score=0.7324556945845797, total=   8.3s
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed:  7.3min remaining:    0.0s
# [CV] max_depth=3, n_estimators=20 ....................................
# [CV]  max_depth=3, n_estimators=20, score=0.7317591340740044, total=   8.4s
# [Parallel(n_jobs=1)]: Done  17 out of  17 | elapsed:  7.5min remaining:    0.0s
# [CV] max_depth=3, n_estimators=20 ....................................
# [CV]  max_depth=3, n_estimators=20, score=0.7285997347297684, total=   8.4s
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed:  7.6min remaining:    0.0s
# [CV] max_depth=3, n_estimators=20 ....................................
# [CV]  max_depth=3, n_estimators=20, score=0.7413669088647328, total=   8.5s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:  7.8min remaining:    0.0s
# [CV] max_depth=3, n_estimators=20 ....................................
# [CV]  max_depth=3, n_estimators=20, score=0.7366052595809202, total=   8.2s
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed:  8.0min remaining:    0.0s
# [CV] max_depth=3, n_estimators=250 ...................................
# [CV]  max_depth=3, n_estimators=250, score=0.7382923771790058, total= 1.4min
# [Parallel(n_jobs=1)]: Done  21 out of  21 | elapsed:  9.5min remaining:    0.0s
# [CV] max_depth=3, n_estimators=250 ...................................
# [CV]  max_depth=3, n_estimators=250, score=0.7371072007474861, total= 1.5min
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed: 11.0min remaining:    0.0s
# [CV] max_depth=3, n_estimators=250 ...................................
# [CV]  max_depth=3, n_estimators=250, score=0.731396069424258, total= 1.4min
# [Parallel(n_jobs=1)]: Done  23 out of  23 | elapsed: 12.5min remaining:    0.0s
# [CV] max_depth=3, n_estimators=250 ...................................
# [CV]  max_depth=3, n_estimators=250, score=0.7425635995470781, total= 1.4min
# [Parallel(n_jobs=1)]: Done  24 out of  24 | elapsed: 14.0min remaining:    0.0s
# [CV] max_depth=3, n_estimators=250 ...................................
# [CV]  max_depth=3, n_estimators=250, score=0.7377849805635752, total= 1.5min
# [Parallel(n_jobs=1)]: Done  25 out of  25 | elapsed: 15.5min remaining:    0.0s
# [CV] max_depth=3, n_estimators=300 ...................................
# [CV]  max_depth=3, n_estimators=300, score=0.7385891555366323, total= 1.8min
# [Parallel(n_jobs=1)]: Done  26 out of  26 | elapsed: 17.4min remaining:    0.0s
# [CV] max_depth=3, n_estimators=300 ...................................
# [CV]  max_depth=3, n_estimators=300, score=0.7370518190005811, total= 1.8min
# [Parallel(n_jobs=1)]: Done  27 out of  27 | elapsed: 19.2min remaining:    0.0s
# [CV] max_depth=3, n_estimators=300 ...................................
# [CV]  max_depth=3, n_estimators=300, score=0.7314556691042864, total= 1.8min
# [Parallel(n_jobs=1)]: Done  28 out of  28 | elapsed: 21.1min remaining:    0.0s
# [CV] max_depth=3, n_estimators=300 ...................................
# [CV]  max_depth=3, n_estimators=300, score=0.742287556486327, total= 1.8min
# [Parallel(n_jobs=1)]: Done  29 out of  29 | elapsed: 22.9min remaining:    0.0s
# [CV] max_depth=3, n_estimators=300 ...................................
# [CV]  max_depth=3, n_estimators=300, score=0.7376175670929683, total= 1.8min
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed: 24.7min remaining:    0.0s
# [CV] max_depth=5, n_estimators=20 ....................................
# [CV]  max_depth=5, n_estimators=20, score=0.7441386194215214, total=  13.2s
# [Parallel(n_jobs=1)]: Done  31 out of  31 | elapsed: 25.0min remaining:    0.0s
# [CV] max_depth=5, n_estimators=20 ....................................
# [CV]  max_depth=5, n_estimators=20, score=0.744114432739383, total=  12.8s
# [Parallel(n_jobs=1)]: Done  32 out of  32 | elapsed: 25.2min remaining:    0.0s
# [CV] max_depth=5, n_estimators=20 ....................................
# [CV]  max_depth=5, n_estimators=20, score=0.7367479247564193, total=  12.8s
# [Parallel(n_jobs=1)]: Done  33 out of  33 | elapsed: 25.4min remaining:    0.0s
# [CV] max_depth=5, n_estimators=20 ....................................
# [CV]  max_depth=5, n_estimators=20, score=0.7503091283642982, total=  13.0s
# [Parallel(n_jobs=1)]: Done  34 out of  34 | elapsed: 25.7min remaining:    0.0s
# [CV] max_depth=5, n_estimators=20 ....................................
# [CV]  max_depth=5, n_estimators=20, score=0.7451329460280367, total=  13.0s
# [Parallel(n_jobs=1)]: Done  35 out of  35 | elapsed: 25.9min remaining:    0.0s
# [CV] max_depth=5, n_estimators=250 ...................................
# [CV]  max_depth=5, n_estimators=250, score=0.7465241372475488, total= 2.4min
# [Parallel(n_jobs=1)]: Done  36 out of  36 | elapsed: 28.4min remaining:    0.0s
# [CV] max_depth=5, n_estimators=250 ...................................
# [CV]  max_depth=5, n_estimators=250, score=0.7462740982159621, total= 2.4min
# [Parallel(n_jobs=1)]: Done  37 out of  37 | elapsed: 30.9min remaining:    0.0s
# [CV] max_depth=5, n_estimators=250 ...................................
# [CV]  max_depth=5, n_estimators=250, score=0.7391959148177718, total= 2.3min
# [Parallel(n_jobs=1)]: Done  38 out of  38 | elapsed: 33.3min remaining:    0.0s
# [CV] max_depth=5, n_estimators=250 ...................................
# [CV]  max_depth=5, n_estimators=250, score=0.7505084363917072, total= 2.4min
# [Parallel(n_jobs=1)]: Done  39 out of  39 | elapsed: 35.8min remaining:    0.0s
# [CV] max_depth=5, n_estimators=250 ...................................
# [CV]  max_depth=5, n_estimators=250, score=0.7469944670442894, total= 2.5min
# [Parallel(n_jobs=1)]: Done  40 out of  40 | elapsed: 38.3min remaining:    0.0s
# [CV] max_depth=5, n_estimators=300 ...................................
# [CV]  max_depth=5, n_estimators=300, score=0.746853112400194, total= 3.0min
# [Parallel(n_jobs=1)]: Done  41 out of  41 | elapsed: 41.4min remaining:    0.0s
# [CV] max_depth=5, n_estimators=300 ...................................
# [CV]  max_depth=5, n_estimators=300, score=0.7464220108707608, total= 2.9min
# [Parallel(n_jobs=1)]: Done  42 out of  42 | elapsed: 44.4min remaining:    0.0s
# [CV] max_depth=5, n_estimators=300 ...................................
# [CV]  max_depth=5, n_estimators=300, score=0.7395282587358551, total= 2.9min
# [Parallel(n_jobs=1)]: Done  43 out of  43 | elapsed: 47.4min remaining:    0.0s
# [CV] max_depth=5, n_estimators=300 ...................................
# [CV]  max_depth=5, n_estimators=300, score=0.7506116083183839, total= 2.9min
# [Parallel(n_jobs=1)]: Done  44 out of  44 | elapsed: 50.4min remaining:    0.0s
# [CV] max_depth=5, n_estimators=300 ...................................
# [CV]  max_depth=5, n_estimators=300, score=0.7468409399785088, total= 2.8min
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed: 53.3min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed: 53.3min finished
# {'max_depth': 5, 'n_estimators': 300}
# ------------
# 0.7135590593084519 {'max_depth': 1, 'n_estimators': 20}
# 0.7236269671701595 {'max_depth': 1, 'n_estimators': 250}
# 0.7246339811357244 {'max_depth': 1, 'n_estimators': 300}
# 0.7341573408331721 {'max_depth': 3, 'n_estimators': 20}
# 0.7374288483004133 {'max_depth': 3, 'n_estimators': 250}
# 0.7374003573100438 {'max_depth': 3, 'n_estimators': 300}
# 0.7440886104245574 {'max_depth': 5, 'n_estimators': 20}
# 0.745899412775014 {'max_depth': 5, 'n_estimators': 250}
# 0.7460511886685377 {'max_depth': 5, 'n_estimators': 300}

# %%
### Forgot None!
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

final_rf = RandomForestClassifier(random_state=123)

param_grid = {'n_estimators': [20, 250, 300], 'max_depth' : [None]}
grid_search_final_rf = GridSearchCV(estimator=final_rf, param_grid=param_grid , cv=5, scoring='roc_auc', verbose=100)

grid_search_final_rf.fit(training_df, y_train)

# Results of the grid search for best n_estimator
print(grid_search_final_rf.best_params_)
print ("------------")

# Results of the grid search in general
cvres = grid_search_final_rf.cv_results_
for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]):
    print(mean_score, params)
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [CV] max_depth=None, n_estimators=20 .................................
# [CV]  max_depth=None, n_estimators=20, score=0.693795355560664, total= 1.0min
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  1.1min remaining:    0.0s
# [CV] max_depth=None, n_estimators=20 .................................
# [CV]  max_depth=None, n_estimators=20, score=0.6910975284639682, total= 1.1min
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:  2.3min remaining:    0.0s
# [CV] max_depth=None, n_estimators=20 .................................
# [CV]  max_depth=None, n_estimators=20, score=0.6871995847045846, total= 1.1min
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:  3.4min remaining:    0.0s
# [CV] max_depth=None, n_estimators=20 .................................
# [CV]  max_depth=None, n_estimators=20, score=0.6938310056238336, total= 1.1min
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:  4.5min remaining:    0.0s
# [CV] max_depth=None, n_estimators=20 .................................
# [CV]  max_depth=None, n_estimators=20, score=0.6922888345129385, total= 1.1min
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:  5.6min remaining:    0.0s
# [CV] max_depth=None, n_estimators=250 ................................
# [CV]  max_depth=None, n_estimators=250, score=0.7481188546932422, total=13.1min
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed: 19.3min remaining:    0.0s
# [CV] max_depth=None, n_estimators=250 ................................
# [CV]  max_depth=None, n_estimators=250, score=0.7444499935439618, total=13.5min
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed: 33.3min remaining:    0.0s
# [CV] max_depth=None, n_estimators=250 ................................
# [CV]  max_depth=None, n_estimators=250, score=0.7413521478800228, total=13.3min
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed: 47.1min remaining:    0.0s
# [CV] max_depth=None, n_estimators=250 ................................
# [CV]  max_depth=None, n_estimators=250, score=0.7461998942987383, total=13.2min
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed: 60.9min remaining:    0.0s
# [CV] max_depth=None, n_estimators=250 ................................
# [CV]  max_depth=None, n_estimators=250, score=0.7441562041708341, total=13.3min
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed: 74.7min remaining:    0.0s
# [CV] max_depth=None, n_estimators=300 ................................
# [CV]  max_depth=None, n_estimators=300, score=0.7496584478629762, total=15.8min
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed: 91.1min remaining:    0.0s
# [CV] max_depth=None, n_estimators=300 ................................
# [CV]  max_depth=None, n_estimators=300, score=0.7459457691717217, total=21.1min
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed: 112.8min remaining:    0.0s
# [CV] max_depth=None, n_estimators=300 ................................
# [CV]  max_depth=None, n_estimators=300, score=0.7421548804024478, total=15.5min
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed: 128.9min remaining:    0.0s
# [CV] max_depth=None, n_estimators=300 ................................
# [CV]  max_depth=None, n_estimators=300, score=0.747126063707783, total=15.3min
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed: 144.9min remaining:    0.0s
# [CV] max_depth=None, n_estimators=300 ................................
# [CV]  max_depth=None, n_estimators=300, score=0.7451111403112731, total=15.6min
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed: 161.1min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed: 161.1min finished
# {'max_depth': None, 'n_estimators': 300}
# ------------
# 0.691642468774228 {'max_depth': None, 'n_estimators': 20}
# 0.7448554295297796 {'max_depth': None, 'n_estimators': 250}
# 0.7459992721906117 {'max_depth': None, 'n_estimators': 300}

# %%
## NONE was not any better, and was longer in comparion to max_depth = 5. As such, this parameter value
## can be ignored.

# %%
# Find BEST model
from sklearn.model_selection import cross_val_predict

forest_final_clf = grid_search_final_rf.best_estimator_
y_probas_final_forest = cross_val_predict(forest_final_clf, training_df, y_train, cv=3, method="predict_proba")
y_scores_final_forest = y_probas_final_forest[:, 1] 
fpr_final_forest, tpr_final_forest, thresholds_final_forest = roc_curve(y_train, y_scores_final_forest)

print ("AUC: ", auc(fpr_final_forest, tpr_final_forest))
# Out:
# AUC:  0.7467176950695793

# %%
predictions = forest_final_clf.predict_proba(testing_df)[:, 1]
submit = load_credit_data ("submit_labels.csv")
submit['TARGET'] = predictions
submit.to_csv('random_forest_features_final.csv', index = False)

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV

log_rf = LogisticRegression(random_state=123)

param_grid = {'C': [0.01, 0.1, 1, 10, 100, 1000],'penalty': ['l1', 'l2']}

grid_search_log_rf = GridSearchCV(estimator=log_rf, param_grid=param_grid , cv=5, scoring='roc_auc', verbose=100)

grid_search_log_rf.fit(training_df, y_train)

# Results of the grid search for best n_estimator
print(grid_search_log_rf.best_params_)
print ("------------")

# Results of the grid search in general
cvres = grid_search_log_rf.cv_results_
for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]):
    print(mean_score, params)
# Out:
# Fitting 5 folds for each of 14 candidates, totalling 70 fits
# [CV] C=0.001, penalty=l1 .............................................
# [CV] ..... C=0.001, penalty=l1, score=0.730554573229131, total= 2.8min
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  2.8min remaining:    0.0s
# [CV] C=0.001, penalty=l1 .............................................
# [CV] .... C=0.001, penalty=l1, score=0.7275172951734359, total= 3.8min
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:  6.6min remaining:    0.0s
# [CV] C=0.001, penalty=l1 .............................................
# [CV] .... C=0.001, penalty=l1, score=0.7271524403958223, total= 2.4min
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:  9.1min remaining:    0.0s
# [CV] C=0.001, penalty=l1 .............................................
# [CV] .... C=0.001, penalty=l1, score=0.7303388893736781, total= 3.8min
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed: 12.9min remaining:    0.0s
# [CV] C=0.001, penalty=l1 .............................................
# [CV] .... C=0.001, penalty=l1, score=0.7350712642778952, total= 3.9min
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed: 16.8min remaining:    0.0s
# [CV] C=0.001, penalty=l2 .............................................
# [CV] .... C=0.001, penalty=l2, score=0.6358708454672466, total= 2.1min
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed: 19.0min remaining:    0.0s
# [CV] C=0.001, penalty=l2 .............................................
# [CV] .... C=0.001, penalty=l2, score=0.6358006264948792, total= 2.2min
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed: 21.2min remaining:    0.0s
# [CV] C=0.001, penalty=l2 .............................................
# [CV] .... C=0.001, penalty=l2, score=0.6443059639525959, total= 2.5min
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed: 23.7min remaining:    0.0s
# [CV] C=0.001, penalty=l2 .............................................
# [CV] .... C=0.001, penalty=l2, score=0.6345845970879056, total= 2.0min
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed: 25.7min remaining:    0.0s
# [CV] C=0.001, penalty=l2 .............................................
# [CV] .... C=0.001, penalty=l2, score=0.6337692072036669, total= 2.0min
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed: 27.7min remaining:    0.0s
# [CV] C=0.01, penalty=l1 ..............................................
# [CV] ..... C=0.01, penalty=l1, score=0.7666971214576178, total= 3.1min
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed: 30.8min remaining:    0.0s
# [CV] C=0.01, penalty=l1 ..............................................
# [CV] ..... C=0.01, penalty=l1, score=0.7637428392436141, total= 4.1min
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed: 34.9min remaining:    0.0s
# [CV] C=0.01, penalty=l1 ..............................................
# [CV] ..... C=0.01, penalty=l1, score=0.7581980134710595, total= 3.3min
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed: 38.2min remaining:    0.0s
# [CV] C=0.01, penalty=l1 ..............................................
# [CV] ..... C=0.01, penalty=l1, score=0.7658958554193699, total= 3.2min
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed: 41.4min remaining:    0.0s
# [CV] C=0.01, penalty=l1 ..............................................
# [CV] ..... C=0.01, penalty=l1, score=0.7683730112057907, total= 3.4min
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed: 44.8min remaining:    0.0s
# [CV] C=0.01, penalty=l2 ..............................................
# [CV] ...... C=0.01, penalty=l2, score=0.652728881433539, total= 2.9min
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed: 47.8min remaining:    0.0s
# [CV] C=0.01, penalty=l2 ..............................................
# [CV] ...... C=0.01, penalty=l2, score=0.630671979623678, total= 1.9min
# [Parallel(n_jobs=1)]: Done  17 out of  17 | elapsed: 49.7min remaining:    0.0s
# [CV] C=0.01, penalty=l2 ..............................................
# [CV] ..... C=0.01, penalty=l2, score=0.6580754636328756, total= 3.7min
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed: 53.4min remaining:    0.0s
# [CV] C=0.01, penalty=l2 ..............................................
# [CV] ...... C=0.01, penalty=l2, score=0.644307054060312, total= 2.2min
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed: 55.6min remaining:    0.0s
# [CV] C=0.01, penalty=l2 ..............................................
# [CV] ..... C=0.01, penalty=l2, score=0.6354066523039632, total= 2.0min
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed: 57.6min remaining:    0.0s
# [CV] C=0.1, penalty=l1 ...............................................
# [CV] ...... C=0.1, penalty=l1, score=0.7721445854826512, total= 4.5min
# [Parallel(n_jobs=1)]: Done  21 out of  21 | elapsed: 62.1min remaining:    0.0s
# [CV] C=0.1, penalty=l1 ...............................................
# [CV] ...... C=0.1, penalty=l1, score=0.7698452729251212, total= 3.8min
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed: 65.9min remaining:    0.0s
# [CV] C=0.1, penalty=l1 ...............................................
# [CV] ...... C=0.1, penalty=l1, score=0.7642733761442858, total= 4.5min
# [Parallel(n_jobs=1)]: Done  23 out of  23 | elapsed: 70.4min remaining:    0.0s
# [CV] C=0.1, penalty=l1 ...............................................
# [CV] ...... C=0.1, penalty=l1, score=0.7720322783744663, total= 4.4min
# [Parallel(n_jobs=1)]: Done  24 out of  24 | elapsed: 74.8min remaining:    0.0s
# [CV] C=0.1, penalty=l1 ...............................................
# [CV] ...... C=0.1, penalty=l1, score=0.7743149568068862, total= 4.8min
# [Parallel(n_jobs=1)]: Done  25 out of  25 | elapsed: 79.6min remaining:    0.0s
# [CV] C=0.1, penalty=l2 ...............................................
# [CV] ...... C=0.1, penalty=l2, score=0.6363318745028921, total= 2.4min
# [Parallel(n_jobs=1)]: Done  26 out of  26 | elapsed: 82.0min remaining:    0.0s
# [CV] C=0.1, penalty=l2 ...............................................
# [CV] ...... C=0.1, penalty=l2, score=0.6468016515701889, total= 2.6min
# [Parallel(n_jobs=1)]: Done  27 out of  27 | elapsed: 84.7min remaining:    0.0s
# [CV] C=0.1, penalty=l2 ...............................................
# [CV] ...... C=0.1, penalty=l2, score=0.6442305113989197, total= 2.2min
# [Parallel(n_jobs=1)]: Done  28 out of  28 | elapsed: 86.9min remaining:    0.0s
# [CV] C=0.1, penalty=l2 ...............................................
# [CV] ...... C=0.1, penalty=l2, score=0.6404331852942118, total= 2.1min
# [Parallel(n_jobs=1)]: Done  29 out of  29 | elapsed: 89.1min remaining:    0.0s
# [CV] C=0.1, penalty=l2 ...............................................
# [CV] ...... C=0.1, penalty=l2, score=0.6294486935192615, total= 1.8min
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed: 90.9min remaining:    0.0s
# [CV] C=1, penalty=l1 .................................................
# [CV] ........ C=1, penalty=l1, score=0.7722849610865147, total= 6.8min
# [Parallel(n_jobs=1)]: Done  31 out of  31 | elapsed: 97.7min remaining:    0.0s
# [CV] C=1, penalty=l1 .................................................
# [CV] ........ C=1, penalty=l1, score=0.7705423718723995, total= 7.0min
# [Parallel(n_jobs=1)]: Done  32 out of  32 | elapsed: 104.7min remaining:    0.0s
# [CV] C=1, penalty=l1 .................................................
# [CV] ........ C=1, penalty=l1, score=0.7645765329626397, total= 5.5min
# [Parallel(n_jobs=1)]: Done  33 out of  33 | elapsed: 110.3min remaining:    0.0s
# [CV] C=1, penalty=l1 .................................................
# [CV] ........ C=1, penalty=l1, score=0.7723361761810716, total= 5.7min
# [Parallel(n_jobs=1)]: Done  34 out of  34 | elapsed: 116.0min remaining:    0.0s
# [CV] C=1, penalty=l1 .................................................
# [CV] ........ C=1, penalty=l1, score=0.7749431972834372, total= 7.1min
# [Parallel(n_jobs=1)]: Done  35 out of  35 | elapsed: 123.1min remaining:    0.0s
# [CV] C=1, penalty=l2 .................................................
# [CV] ........ C=1, penalty=l2, score=0.6291061912498886, total= 2.2min
# [Parallel(n_jobs=1)]: Done  36 out of  36 | elapsed: 125.3min remaining:    0.0s
# [CV] C=1, penalty=l2 .................................................
# [CV] ........ C=1, penalty=l2, score=0.6315480236712259, total= 2.3min
# [Parallel(n_jobs=1)]: Done  37 out of  37 | elapsed: 127.6min remaining:    0.0s
# [CV] C=1, penalty=l2 .................................................
# [CV] ........ C=1, penalty=l2, score=0.6477344132809604, total= 2.9min
# [Parallel(n_jobs=1)]: Done  38 out of  38 | elapsed: 130.6min remaining:    0.0s
# [CV] C=1, penalty=l2 .................................................
# [CV] .......... C=1, penalty=l2, score=0.66134786368545, total= 5.4min
# [Parallel(n_jobs=1)]: Done  39 out of  39 | elapsed: 135.9min remaining:    0.0s
# [CV] C=1, penalty=l2 .................................................
# [CV] ........ C=1, penalty=l2, score=0.6284092116880707, total= 2.2min
# [Parallel(n_jobs=1)]: Done  40 out of  40 | elapsed: 138.2min remaining:    0.0s
# [CV] C=10, penalty=l1 ................................................
# [CV] ....... C=10, penalty=l1, score=0.7722763151890251, total= 7.7min
# [Parallel(n_jobs=1)]: Done  41 out of  41 | elapsed: 145.9min remaining:    0.0s
# [CV] C=10, penalty=l1 ................................................
# [CV] ....... C=10, penalty=l1, score=0.7704469375730401, total= 8.0min
# [Parallel(n_jobs=1)]: Done  42 out of  42 | elapsed: 154.0min remaining:    0.0s
# [CV] C=10, penalty=l1 ................................................
# [CV] ....... C=10, penalty=l1, score=0.7645700885023186, total= 7.0min
# [Parallel(n_jobs=1)]: Done  43 out of  43 | elapsed: 161.0min remaining:    0.0s
# [CV] C=10, penalty=l1 ................................................
# [CV] ....... C=10, penalty=l1, score=0.7721726742734454, total= 6.9min
# [Parallel(n_jobs=1)]: Done  44 out of  44 | elapsed: 167.8min remaining:    0.0s
# [CV] C=10, penalty=l1 ................................................
# [CV] ....... C=10, penalty=l1, score=0.7748819766916089, total= 6.6min
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed: 174.4min remaining:    0.0s
# [CV] C=10, penalty=l2 ................................................
# [CV] ....... C=10, penalty=l2, score=0.6359257453132343, total= 2.1min
# [Parallel(n_jobs=1)]: Done  46 out of  46 | elapsed: 176.5min remaining:    0.0s
# [CV] C=10, penalty=l2 ................................................
# [CV] ....... C=10, penalty=l2, score=0.6508164149773604, total= 3.4min
# [Parallel(n_jobs=1)]: Done  47 out of  47 | elapsed: 179.9min remaining:    0.0s
# [CV] C=10, penalty=l2 ................................................
# [CV] ....... C=10, penalty=l2, score=0.6450816895907235, total= 2.7min
# [Parallel(n_jobs=1)]: Done  48 out of  48 | elapsed: 182.7min remaining:    0.0s
# [CV] C=10, penalty=l2 ................................................
# [CV] ....... C=10, penalty=l2, score=0.6406868562096801, total= 2.4min
# [Parallel(n_jobs=1)]: Done  49 out of  49 | elapsed: 185.1min remaining:    0.0s
# [CV] C=10, penalty=l2 ................................................
# [CV] ....... C=10, penalty=l2, score=0.6286346181766804, total= 2.2min
# [Parallel(n_jobs=1)]: Done  50 out of  50 | elapsed: 187.2min remaining:    0.0s
# [CV] C=100, penalty=l1 ...............................................
# [CV] ...... C=100, penalty=l1, score=0.7723175960543359, total= 7.3min
# [Parallel(n_jobs=1)]: Done  51 out of  51 | elapsed: 194.6min remaining:    0.0s
# [CV] C=100, penalty=l1 ...............................................
# [CV] ...... C=100, penalty=l1, score=0.7705861008665627, total= 8.0min
# [Parallel(n_jobs=1)]: Done  52 out of  52 | elapsed: 202.6min remaining:    0.0s
# [CV] C=100, penalty=l1 ...............................................
# [CV] ...... C=100, penalty=l1, score=0.7646474149012845, total= 7.7min
# [Parallel(n_jobs=1)]: Done  53 out of  53 | elapsed: 210.3min remaining:    0.0s
# [CV] C=100, penalty=l1 ...............................................
# [CV] ...... C=100, penalty=l1, score=0.7721892788226752, total= 7.5min
# [Parallel(n_jobs=1)]: Done  54 out of  54 | elapsed: 217.9min remaining:    0.0s
# [CV] C=100, penalty=l1 ...............................................
# [CV] ...... C=100, penalty=l1, score=0.7749065789265328, total= 7.2min
# [Parallel(n_jobs=1)]: Done  55 out of  55 | elapsed: 225.0min remaining:    0.0s
# [CV] C=100, penalty=l2 ...............................................
# [CV] ...... C=100, penalty=l2, score=0.6631654914195257, total= 4.8min
# [Parallel(n_jobs=1)]: Done  56 out of  56 | elapsed: 229.8min remaining:    0.0s
# [CV] C=100, penalty=l2 ...............................................
# [CV] ...... C=100, penalty=l2, score=0.6338098261846403, total= 2.2min
# [Parallel(n_jobs=1)]: Done  57 out of  57 | elapsed: 232.0min remaining:    0.0s
# [CV] C=100, penalty=l2 ...............................................
# [CV] ...... C=100, penalty=l2, score=0.6498431981580172, total= 3.1min
# [Parallel(n_jobs=1)]: Done  58 out of  58 | elapsed: 235.1min remaining:    0.0s
# [CV] C=100, penalty=l2 ...............................................
# [CV] ...... C=100, penalty=l2, score=0.6417286073173908, total= 2.5min
# [Parallel(n_jobs=1)]: Done  59 out of  59 | elapsed: 237.6min remaining:    0.0s
# [CV] C=100, penalty=l2 ...............................................
# [CV] ...... C=100, penalty=l2, score=0.6327809426229106, total= 2.2min
# [Parallel(n_jobs=1)]: Done  60 out of  60 | elapsed: 239.8min remaining:    0.0s
# [CV] C=1000, penalty=l1 ..............................................
# [CV] ..... C=1000, penalty=l1, score=0.7723144860961536, total= 7.1min
# [Parallel(n_jobs=1)]: Done  61 out of  61 | elapsed: 246.9min remaining:    0.0s
# [CV] C=1000, penalty=l1 ..............................................
# [CV] ..... C=1000, penalty=l1, score=0.7705895635616606, total= 7.4min
# [Parallel(n_jobs=1)]: Done  62 out of  62 | elapsed: 254.3min remaining:    0.0s
# [CV] C=1000, penalty=l1 ..............................................
# [CV] ..... C=1000, penalty=l1, score=0.7646434962134163, total= 6.8min
# [Parallel(n_jobs=1)]: Done  63 out of  63 | elapsed: 261.1min remaining:    0.0s
# [CV] C=1000, penalty=l1 ..............................................
# [CV] ..... C=1000, penalty=l1, score=0.7721843377135179, total= 6.8min
# [Parallel(n_jobs=1)]: Done  64 out of  64 | elapsed: 267.9min remaining:    0.0s
# [CV] C=1000, penalty=l1 ..............................................
# [CV] ..... C=1000, penalty=l1, score=0.7749078115319894, total= 6.6min
# [Parallel(n_jobs=1)]: Done  65 out of  65 | elapsed: 274.6min remaining:    0.0s
# [CV] C=1000, penalty=l2 ..............................................
# [CV] ..... C=1000, penalty=l2, score=0.6500682569916971, total= 2.6min
# [Parallel(n_jobs=1)]: Done  66 out of  66 | elapsed: 277.2min remaining:    0.0s
# [CV] C=1000, penalty=l2 ..............................................
# [CV] ..... C=1000, penalty=l2, score=0.6350377612778457, total= 2.0min
# [Parallel(n_jobs=1)]: Done  67 out of  67 | elapsed: 279.2min remaining:    0.0s
# [CV] C=1000, penalty=l2 ..............................................
# [CV] ..... C=1000, penalty=l2, score=0.6699160390843515, total= 5.7min
# [Parallel(n_jobs=1)]: Done  68 out of  68 | elapsed: 284.9min remaining:    0.0s
# [CV] C=1000, penalty=l2 ..............................................
# [CV] ..... C=1000, penalty=l2, score=0.6466931965397773, total= 2.2min
# [Parallel(n_jobs=1)]: Done  69 out of  69 | elapsed: 287.2min remaining:    0.0s
# [CV] C=1000, penalty=l2 ..............................................
# [CV] ..... C=1000, penalty=l2, score=0.6303892747935516, total= 1.8min
# [Parallel(n_jobs=1)]: Done  70 out of  70 | elapsed: 289.0min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  70 out of  70 | elapsed: 289.0min finished
# {'C': 1, 'penalty': 'l1'}
# ------------
# 0.7301268938807745 {'C': 0.001, 'penalty': 'l1'}
# 0.6368662448042931 {'C': 0.001, 'penalty': 'l2'}
# 0.7645813750397427 {'C': 0.01, 'penalty': 'l1'}
# 0.6442380338224882 {'C': 0.01, 'penalty': 'l2'}
# 0.7705220992228886 {'C': 0.1, 'penalty': 'l1'}
# 0.639449173119868 {'C': 0.1, 'penalty': 'l2'}
# 0.7709366522618142 {'C': 1, 'penalty': 'l1'}
# 0.6396291064953693 {'C': 1, 'penalty': 'l2'}
# 0.7708696030204125 {'C': 10, 'penalty': 'l1'}
# 0.6402290508595013 {'C': 10, 'penalty': 'l2'}
# 0.7709293984285953 {'C': 100, 'penalty': 'l1'}
# 0.6442656746013171 {'C': 100, 'penalty': 'l2'}
# 0.7709279435322824 {'C': 1000, 'penalty': 'l1'}
# 0.6464209175983252 {'C': 1000, 'penalty': 'l2'}

# %%
# Find BEST model
from sklearn.model_selection import cross_val_predict

log_final_clf = grid_search_log_rf.best_estimator_
y_probas_log_final = cross_val_predict(log_final_clf, training_df, y_train, cv=3, method="predict_proba")
y_scores_log_final = y_probas_log_final[:, 1] 
fpr_log_final, tpr_log_final, thresholds_log_final = roc_curve(y_train, y_scores_log_final)

print ("AUC: ", auc(fpr_log_final, tpr_log_final))
# Out:
# AUC:  0.7702487533647071

# %%
predictions = log_final_clf.predict_proba(testing_df)[:, 1]
submit = load_credit_data ("submit_labels.csv")
submit['TARGET'] = predictions
submit.to_csv('log_features_final.csv', index = False)

# %% [markdown]
# ### SGD

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(training_df)

X_tr = scaler.transform(training_df)
X_te = scaler.transform(testing_df)

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import GridSearchCV

model_sgd = SGDClassifier(random_state=123)

param_distributions = {'loss': ['log', 'modified_huber'], 'alpha': [1e-3, 1e-2, 1e-1, 1e0, 1e1, 1e2], 'penalty': ['l1', 'l2']}

grid_search_sgd_cv = GridSearchCV(model_sgd, param_distributions, cv=5, scoring='roc_auc', verbose=100) 
grid_search_sgd_cv.fit(X_tr, y_train)

# Results of the grid search for best n_estimator
print(grid_search_sgd_cv.best_params_)
print ("------------")

# Results of the grid search in general
cvres = grid_search_sgd_cv.cv_results_
for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]):
    print(mean_score, params)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV] alpha=0.001, loss=log, penalty=l1 ...............................
# [CV]  alpha=0.001, loss=log, penalty=l1, score=0.7296241043774638, total=   8.1s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    8.3s remaining:    0.0s
# [CV] alpha=0.001, loss=log, penalty=l1 ...............................
# [CV]  alpha=0.001, loss=log, penalty=l1, score=0.7213308875733616, total=   8.1s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:   16.6s remaining:    0.0s
# [CV] alpha=0.001, loss=log, penalty=l1 ...............................
# [CV]  alpha=0.001, loss=log, penalty=l1, score=0.7173434124835253, total=   7.6s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:   24.5s remaining:    0.0s
# [CV] alpha=0.001, loss=log, penalty=l1 ...............................
# [CV]  alpha=0.001, loss=log, penalty=l1, score=0.7293571975012095, total=   7.8s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:   32.5s remaining:    0.0s
# [CV] alpha=0.001, loss=log, penalty=l1 ...............................
# [CV]  alpha=0.001, loss=log, penalty=l1, score=0.7367334826104041, total=   8.4s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:   41.1s remaining:    0.0s
# [CV] alpha=0.001, loss=log, penalty=l2 ...............................
# [CV]  alpha=0.001, loss=log, penalty=l2, score=0.7594177139441939, total=   5.3s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:   46.6s remaining:    0.0s
# [CV] alpha=0.001, loss=log, penalty=l2 ...............................
# [CV]  alpha=0.001, loss=log, penalty=l2, score=0.7571380190901017, total=   5.9s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:   52.7s remaining:    0.0s
# [CV] alpha=0.001, loss=log, penalty=l2 ...............................
# [CV]  alpha=0.001, loss=log, penalty=l2, score=0.749604662283828, total=   5.6s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:   58.6s remaining:    0.0s
# [CV] alpha=0.001, loss=log, penalty=l2 ...............................
# [CV]  alpha=0.001, loss=log, penalty=l2, score=0.7485419426335802, total=   5.9s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:  1.1min remaining:    0.0s
# [CV] alpha=0.001, loss=log, penalty=l2 ...............................
# [CV]  alpha=0.001, loss=log, penalty=l2, score=0.7592906469595141, total=   5.8s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:  1.2min remaining:    0.0s
# [CV] alpha=0.001, loss=modified_huber, penalty=l1 ....................
# [CV]  alpha=0.001, loss=modified_huber, penalty=l1, score=0.7279547479353956, total=   6.5s
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed:  1.3min remaining:    0.0s
# [CV] alpha=0.001, loss=modified_huber, penalty=l1 ....................
# [CV]  alpha=0.001, loss=modified_huber, penalty=l1, score=0.7419846632887933, total=   5.9s
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:  1.4min remaining:    0.0s
# [CV] alpha=0.001, loss=modified_huber, penalty=l1 ....................
# [CV]  alpha=0.001, loss=modified_huber, penalty=l1, score=0.7180322857487244, total=   6.5s
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed:  1.5min remaining:    0.0s
# [CV] alpha=0.001, loss=modified_huber, penalty=l1 ....................
# [CV]  alpha=0.001, loss=modified_huber, penalty=l1, score=0.7262255674041833, total=   6.2s
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed:  1.6min remaining:    0.0s
# [CV] alpha=0.001, loss=modified_huber, penalty=l1 ....................
# [CV]  alpha=0.001, loss=modified_huber, penalty=l1, score=0.7404500481205964, total=   6.2s
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:  1.7min remaining:    0.0s
# [CV] alpha=0.001, loss=modified_huber, penalty=l2 ....................
# [CV]  alpha=0.001, loss=modified_huber, penalty=l2, score=0.6673061959023576, total=   5.5s
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed:  1.8min remaining:    0.0s
# [CV] alpha=0.001, loss=modified_huber, penalty=l2 ....................
# [CV]  alpha=0.001, loss=modified_huber, penalty=l2, score=0.70060411739028, total=   4.9s
# [Parallel(n_jobs=1)]: Done  17 out of  17 | elapsed:  1.9min remaining:    0.0s
# [CV] alpha=0.001, loss=modified_huber, penalty=l2 ....................
# [CV]  alpha=0.001, loss=modified_huber, penalty=l2, score=0.6733543314441518, total=   5.2s
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed:  2.0min remaining:    0.0s
# [CV] alpha=0.001, loss=modified_huber, penalty=l2 ....................
# [CV]  alpha=0.001, loss=modified_huber, penalty=l2, score=0.6913777912390643, total=   4.9s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:  2.1min remaining:    0.0s
# [CV] alpha=0.001, loss=modified_huber, penalty=l2 ....................
# [CV]  alpha=0.001, loss=modified_huber, penalty=l2, score=0.6846314387670911, total=   4.9s
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed:  2.2min remaining:    0.0s
# [CV] alpha=0.01, loss=log, penalty=l1 ................................
# [CV]  alpha=0.01, loss=log, penalty=l1, score=0.6914613533191429, total=   8.0s
# [Parallel(n_jobs=1)]: Done  21 out of  21 | elapsed:  2.3min remaining:    0.0s
# [CV] alpha=0.01, loss=log, penalty=l1 ................................
# [CV]  alpha=0.01, loss=log, penalty=l1, score=0.7193649673686409, total=   8.0s
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed:  2.4min remaining:    0.0s
# [CV] alpha=0.01, loss=log, penalty=l1 ................................
# [CV]  alpha=0.01, loss=log, penalty=l1, score=0.6936898705178248, total=   7.8s
# [Parallel(n_jobs=1)]: Done  23 out of  23 | elapsed:  2.6min remaining:    0.0s
# [CV] alpha=0.01, loss=log, penalty=l1 ................................
# [CV]  alpha=0.01, loss=log, penalty=l1, score=0.6898331442299254, total=   7.7s
# [Parallel(n_jobs=1)]: Done  24 out of  24 | elapsed:  2.7min remaining:    0.0s
# [CV] alpha=0.01, loss=log, penalty=l1 ................................
# [CV]  alpha=0.01, loss=log, penalty=l1, score=0.7248589428224431, total=   7.7s
# [Parallel(n_jobs=1)]: Done  25 out of  25 | elapsed:  2.8min remaining:    0.0s
# [CV] alpha=0.01, loss=log, penalty=l2 ................................
# [CV]  alpha=0.01, loss=log, penalty=l2, score=0.7629491124275531, total=   5.6s
# [Parallel(n_jobs=1)]: Done  26 out of  26 | elapsed:  2.9min remaining:    0.0s
# [CV] alpha=0.01, loss=log, penalty=l2 ................................
# [CV]  alpha=0.01, loss=log, penalty=l2, score=0.7587010874946638, total=   6.2s
# [Parallel(n_jobs=1)]: Done  27 out of  27 | elapsed:  3.0min remaining:    0.0s
# [CV] alpha=0.01, loss=log, penalty=l2 ................................
# [CV]  alpha=0.01, loss=log, penalty=l2, score=0.7554942328403464, total=   5.6s
# [Parallel(n_jobs=1)]: Done  28 out of  28 | elapsed:  3.1min remaining:    0.0s
# [CV] alpha=0.01, loss=log, penalty=l2 ................................
# [CV]  alpha=0.01, loss=log, penalty=l2, score=0.7628433863797204, total=   5.5s
# [Parallel(n_jobs=1)]: Done  29 out of  29 | elapsed:  3.2min remaining:    0.0s
# [CV] alpha=0.01, loss=log, penalty=l2 ................................
# [CV]  alpha=0.01, loss=log, penalty=l2, score=0.76335681998907, total=   5.5s
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:  3.3min remaining:    0.0s
# [CV] alpha=0.01, loss=modified_huber, penalty=l1 .....................
# [CV]  alpha=0.01, loss=modified_huber, penalty=l1, score=0.6935605626238529, total=   6.1s
# [Parallel(n_jobs=1)]: Done  31 out of  31 | elapsed:  3.4min remaining:    0.0s
# [CV] alpha=0.01, loss=modified_huber, penalty=l1 .....................
# [CV]  alpha=0.01, loss=modified_huber, penalty=l1, score=0.7163757210140758, total=   5.8s
# [Parallel(n_jobs=1)]: Done  32 out of  32 | elapsed:  3.5min remaining:    0.0s
# [CV] alpha=0.01, loss=modified_huber, penalty=l1 .....................
# [CV]  alpha=0.01, loss=modified_huber, penalty=l1, score=0.6859856660453942, total=   5.8s
# [Parallel(n_jobs=1)]: Done  33 out of  33 | elapsed:  3.6min remaining:    0.0s
# [CV] alpha=0.01, loss=modified_huber, penalty=l1 .....................
# [CV]  alpha=0.01, loss=modified_huber, penalty=l1, score=0.6984437590184371, total=   6.5s
# [Parallel(n_jobs=1)]: Done  34 out of  34 | elapsed:  3.7min remaining:    0.0s
# [CV] alpha=0.01, loss=modified_huber, penalty=l1 .....................
# [CV]  alpha=0.01, loss=modified_huber, penalty=l1, score=0.718022161284251, total=   5.9s
# [Parallel(n_jobs=1)]: Done  35 out of  35 | elapsed:  3.8min remaining:    0.0s
# [CV] alpha=0.01, loss=modified_huber, penalty=l2 .....................
# [CV]  alpha=0.01, loss=modified_huber, penalty=l2, score=0.760197572472802, total=   5.0s
# [Parallel(n_jobs=1)]: Done  36 out of  36 | elapsed:  3.9min remaining:    0.0s
# [CV] alpha=0.01, loss=modified_huber, penalty=l2 .....................
# [CV]  alpha=0.01, loss=modified_huber, penalty=l2, score=0.7581525923162261, total=   5.0s
# [Parallel(n_jobs=1)]: Done  37 out of  37 | elapsed:  4.0min remaining:    0.0s
# [CV] alpha=0.01, loss=modified_huber, penalty=l2 .....................
# [CV]  alpha=0.01, loss=modified_huber, penalty=l2, score=0.753338113776288, total=   4.8s
# [Parallel(n_jobs=1)]: Done  38 out of  38 | elapsed:  4.1min remaining:    0.0s
# [CV] alpha=0.01, loss=modified_huber, penalty=l2 .....................
# [CV]  alpha=0.01, loss=modified_huber, penalty=l2, score=0.7615828691781145, total=   5.0s
# [Parallel(n_jobs=1)]: Done  39 out of  39 | elapsed:  4.2min remaining:    0.0s
# [CV] alpha=0.01, loss=modified_huber, penalty=l2 .....................
# [CV]  alpha=0.01, loss=modified_huber, penalty=l2, score=0.7616467544776931, total=   4.9s
# [Parallel(n_jobs=1)]: Done  40 out of  40 | elapsed:  4.3min remaining:    0.0s
# [CV] alpha=0.1, loss=log, penalty=l1 .................................
# [CV]  alpha=0.1, loss=log, penalty=l1, score=0.4902372623789785, total=   7.8s
# [Parallel(n_jobs=1)]: Done  41 out of  41 | elapsed:  4.4min remaining:    0.0s
# [CV] alpha=0.1, loss=log, penalty=l1 .................................
# [CV] ....... alpha=0.1, loss=log, penalty=l1, score=0.5, total=   7.8s
# [Parallel(n_jobs=1)]: Done  42 out of  42 | elapsed:  4.5min remaining:    0.0s
# [CV] alpha=0.1, loss=log, penalty=l1 .................................
# [CV] ....... alpha=0.1, loss=log, penalty=l1, score=0.5, total=   7.7s
# [Parallel(n_jobs=1)]: Done  43 out of  43 | elapsed:  4.7min remaining:    0.0s
# [CV] alpha=0.1, loss=log, penalty=l1 .................................
# [CV] ....... alpha=0.1, loss=log, penalty=l1, score=0.5, total=   7.6s
# [Parallel(n_jobs=1)]: Done  44 out of  44 | elapsed:  4.8min remaining:    0.0s
# [CV] alpha=0.1, loss=log, penalty=l1 .................................
# [CV] ....... alpha=0.1, loss=log, penalty=l1, score=0.5, total=   7.7s
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed:  4.9min remaining:    0.0s
# [CV] alpha=0.1, loss=log, penalty=l2 .................................
# [CV]  alpha=0.1, loss=log, penalty=l2, score=0.7586744838119551, total=   5.6s
# [Parallel(n_jobs=1)]: Done  46 out of  46 | elapsed:  5.0min remaining:    0.0s
# [CV] alpha=0.1, loss=log, penalty=l2 .................................
# [CV]  alpha=0.1, loss=log, penalty=l2, score=0.7545397722861167, total=   5.5s
# [Parallel(n_jobs=1)]: Done  47 out of  47 | elapsed:  5.1min remaining:    0.0s
# [CV] alpha=0.1, loss=log, penalty=l2 .................................
# [CV]  alpha=0.1, loss=log, penalty=l2, score=0.7514577741521602, total=   5.6s
# [Parallel(n_jobs=1)]: Done  48 out of  48 | elapsed:  5.2min remaining:    0.0s
# [CV] alpha=0.1, loss=log, penalty=l2 .................................
# [CV]  alpha=0.1, loss=log, penalty=l2, score=0.7575660716156951, total=   5.5s
# [Parallel(n_jobs=1)]: Done  49 out of  49 | elapsed:  5.3min remaining:    0.0s
# [CV] alpha=0.1, loss=log, penalty=l2 .................................
# [CV]  alpha=0.1, loss=log, penalty=l2, score=0.7608711143382099, total=   5.5s
# [Parallel(n_jobs=1)]: Done  50 out of  50 | elapsed:  5.4min remaining:    0.0s
# [CV] alpha=0.1, loss=modified_huber, penalty=l1 ......................
# [CV]  alpha=0.1, loss=modified_huber, penalty=l1, score=0.6733263589047774, total=   5.7s
# [Parallel(n_jobs=1)]: Done  51 out of  51 | elapsed:  5.5min remaining:    0.0s
# [CV] alpha=0.1, loss=modified_huber, penalty=l1 ......................
# [CV]  alpha=0.1, loss=modified_huber, penalty=l1, score=0.6471255311224773, total=   5.6s
# [Parallel(n_jobs=1)]: Done  52 out of  52 | elapsed:  5.6min remaining:    0.0s
# [CV] alpha=0.1, loss=modified_huber, penalty=l1 ......................
# [CV]  alpha=0.1, loss=modified_huber, penalty=l1, score=0.6456846153436473, total=   5.7s
# [Parallel(n_jobs=1)]: Done  53 out of  53 | elapsed:  5.7min remaining:    0.0s
# [CV] alpha=0.1, loss=modified_huber, penalty=l1 ......................
# [CV]  alpha=0.1, loss=modified_huber, penalty=l1, score=0.6276720566258948, total=   5.8s
# [Parallel(n_jobs=1)]: Done  54 out of  54 | elapsed:  5.8min remaining:    0.0s
# [CV] alpha=0.1, loss=modified_huber, penalty=l1 ......................
# [CV]  alpha=0.1, loss=modified_huber, penalty=l1, score=0.6602902739538657, total=   5.9s
# [Parallel(n_jobs=1)]: Done  55 out of  55 | elapsed:  5.9min remaining:    0.0s
# [CV] alpha=0.1, loss=modified_huber, penalty=l2 ......................
# [CV]  alpha=0.1, loss=modified_huber, penalty=l2, score=0.753175155089126, total=   4.8s
# [Parallel(n_jobs=1)]: Done  56 out of  56 | elapsed:  6.0min remaining:    0.0s
# [CV] alpha=0.1, loss=modified_huber, penalty=l2 ......................
# [CV]  alpha=0.1, loss=modified_huber, penalty=l2, score=0.750247508778796, total=   4.8s
# [Parallel(n_jobs=1)]: Done  57 out of  57 | elapsed:  6.1min remaining:    0.0s
# [CV] alpha=0.1, loss=modified_huber, penalty=l2 ......................
# [CV]  alpha=0.1, loss=modified_huber, penalty=l2, score=0.747795051413274, total=   4.7s
# [Parallel(n_jobs=1)]: Done  58 out of  58 | elapsed:  6.2min remaining:    0.0s
# [CV] alpha=0.1, loss=modified_huber, penalty=l2 ......................
# [CV]  alpha=0.1, loss=modified_huber, penalty=l2, score=0.753295752760435, total=   5.1s
# [Parallel(n_jobs=1)]: Done  59 out of  59 | elapsed:  6.3min remaining:    0.0s
# [CV] alpha=0.1, loss=modified_huber, penalty=l2 ......................
# [CV]  alpha=0.1, loss=modified_huber, penalty=l2, score=0.7562460295453746, total=   5.6s
# [Parallel(n_jobs=1)]: Done  60 out of  60 | elapsed:  6.4min remaining:    0.0s
# [CV] alpha=1.0, loss=log, penalty=l1 .................................
# [CV] ....... alpha=1.0, loss=log, penalty=l1, score=0.5, total=   8.1s
# [Parallel(n_jobs=1)]: Done  61 out of  61 | elapsed:  6.5min remaining:    0.0s
# [CV] alpha=1.0, loss=log, penalty=l1 .................................
# [CV] ....... alpha=1.0, loss=log, penalty=l1, score=0.5, total=   8.7s
# [Parallel(n_jobs=1)]: Done  62 out of  62 | elapsed:  6.6min remaining:    0.0s
# [CV] alpha=1.0, loss=log, penalty=l1 .................................
# [CV] ....... alpha=1.0, loss=log, penalty=l1, score=0.5, total=   8.6s
# [Parallel(n_jobs=1)]: Done  63 out of  63 | elapsed:  6.8min remaining:    0.0s
# [CV] alpha=1.0, loss=log, penalty=l1 .................................
# [CV] ....... alpha=1.0, loss=log, penalty=l1, score=0.5, total=   7.9s
# [Parallel(n_jobs=1)]: Done  64 out of  64 | elapsed:  6.9min remaining:    0.0s
# [CV] alpha=1.0, loss=log, penalty=l1 .................................
# [CV] ....... alpha=1.0, loss=log, penalty=l1, score=0.5, total=   8.1s
# [Parallel(n_jobs=1)]: Done  65 out of  65 | elapsed:  7.1min remaining:    0.0s
# [CV] alpha=1.0, loss=log, penalty=l2 .................................
# [CV]  alpha=1.0, loss=log, penalty=l2, score=0.7468166336238063, total=   5.6s
# [Parallel(n_jobs=1)]: Done  66 out of  66 | elapsed:  7.2min remaining:    0.0s
# [CV] alpha=1.0, loss=log, penalty=l2 .................................
# [CV]  alpha=1.0, loss=log, penalty=l2, score=0.7463184542001841, total=   5.2s
# [Parallel(n_jobs=1)]: Done  67 out of  67 | elapsed:  7.2min remaining:    0.0s
# [CV] alpha=1.0, loss=log, penalty=l2 .................................
# [CV]  alpha=1.0, loss=log, penalty=l2, score=0.7414477246771228, total=   5.4s
# [Parallel(n_jobs=1)]: Done  68 out of  68 | elapsed:  7.3min remaining:    0.0s
# [CV] alpha=1.0, loss=log, penalty=l2 .................................
# [CV]  alpha=1.0, loss=log, penalty=l2, score=0.7489802728087183, total=   5.7s
# [Parallel(n_jobs=1)]: Done  69 out of  69 | elapsed:  7.4min remaining:    0.0s
# [CV] alpha=1.0, loss=log, penalty=l2 .................................
# [CV]  alpha=1.0, loss=log, penalty=l2, score=0.7517380351460347, total=   5.7s
# [Parallel(n_jobs=1)]: Done  70 out of  70 | elapsed:  7.5min remaining:    0.0s
# [CV] alpha=1.0, loss=modified_huber, penalty=l1 ......................
# [CV]  alpha=1.0, loss=modified_huber, penalty=l1, score=0.456390073469467, total=   6.2s
# [Parallel(n_jobs=1)]: Done  71 out of  71 | elapsed:  7.6min remaining:    0.0s
# [CV] alpha=1.0, loss=modified_huber, penalty=l1 ......................
# [CV]  alpha=1.0, loss=modified_huber, penalty=l1, score=0.5019850416202948, total=   6.3s
# [Parallel(n_jobs=1)]: Done  72 out of  72 | elapsed:  7.8min remaining:    0.0s
# [CV] alpha=1.0, loss=modified_huber, penalty=l1 ......................
# [CV]  alpha=1.0, loss=modified_huber, penalty=l1, score=0.5, total=   6.8s
# [Parallel(n_jobs=1)]: Done  73 out of  73 | elapsed:  7.9min remaining:    0.0s
# [CV] alpha=1.0, loss=modified_huber, penalty=l1 ......................
# [CV]  alpha=1.0, loss=modified_huber, penalty=l1, score=0.5, total=   8.4s
# [Parallel(n_jobs=1)]: Done  74 out of  74 | elapsed:  8.0min remaining:    0.0s
# [CV] alpha=1.0, loss=modified_huber, penalty=l1 ......................
# [CV]  alpha=1.0, loss=modified_huber, penalty=l1, score=0.5, total=   7.8s
# [Parallel(n_jobs=1)]: Done  75 out of  75 | elapsed:  8.1min remaining:    0.0s
# [CV] alpha=1.0, loss=modified_huber, penalty=l2 ......................
# [CV]  alpha=1.0, loss=modified_huber, penalty=l2, score=0.739485097796429, total=   5.0s
# [Parallel(n_jobs=1)]: Done  76 out of  76 | elapsed:  8.2min remaining:    0.0s
# [CV] alpha=1.0, loss=modified_huber, penalty=l2 ......................
# [CV]  alpha=1.0, loss=modified_huber, penalty=l2, score=0.7366005037188259, total=   5.1s
# [Parallel(n_jobs=1)]: Done  77 out of  77 | elapsed:  8.3min remaining:    0.0s
# [CV] alpha=1.0, loss=modified_huber, penalty=l2 ......................
# [CV]  alpha=1.0, loss=modified_huber, penalty=l2, score=0.7416929454765704, total=   5.3s
# [Parallel(n_jobs=1)]: Done  78 out of  78 | elapsed:  8.4min remaining:    0.0s
# [CV] alpha=1.0, loss=modified_huber, penalty=l2 ......................
# [CV]  alpha=1.0, loss=modified_huber, penalty=l2, score=0.7551506672251865, total=   5.1s
# [Parallel(n_jobs=1)]: Done  79 out of  79 | elapsed:  8.5min remaining:    0.0s
# [CV] alpha=1.0, loss=modified_huber, penalty=l2 ......................
# [CV]  alpha=1.0, loss=modified_huber, penalty=l2, score=0.7579072931430212, total=   4.9s
# [Parallel(n_jobs=1)]: Done  80 out of  80 | elapsed:  8.6min remaining:    0.0s
# [CV] alpha=10.0, loss=log, penalty=l1 ................................
# [CV] ...... alpha=10.0, loss=log, penalty=l1, score=0.5, total=   7.9s
# [Parallel(n_jobs=1)]: Done  81 out of  81 | elapsed:  8.7min remaining:    0.0s
# [CV] alpha=10.0, loss=log, penalty=l1 ................................
# [CV] ...... alpha=10.0, loss=log, penalty=l1, score=0.5, total=   7.6s
# [Parallel(n_jobs=1)]: Done  82 out of  82 | elapsed:  8.9min remaining:    0.0s
# [CV] alpha=10.0, loss=log, penalty=l1 ................................
# [CV] ...... alpha=10.0, loss=log, penalty=l1, score=0.5, total=   7.7s
# [Parallel(n_jobs=1)]: Done  83 out of  83 | elapsed:  9.0min remaining:    0.0s
# [CV] alpha=10.0, loss=log, penalty=l1 ................................
# [CV] ...... alpha=10.0, loss=log, penalty=l1, score=0.5, total=   8.1s
# [Parallel(n_jobs=1)]: Done  84 out of  84 | elapsed:  9.1min remaining:    0.0s
# [CV] alpha=10.0, loss=log, penalty=l1 ................................
# [CV] ...... alpha=10.0, loss=log, penalty=l1, score=0.5, total=   7.8s
# [Parallel(n_jobs=1)]: Done  85 out of  85 | elapsed:  9.3min remaining:    0.0s
# [CV] alpha=10.0, loss=log, penalty=l2 ................................
# [CV]  alpha=10.0, loss=log, penalty=l2, score=0.7361427085356098, total=   5.4s
# [Parallel(n_jobs=1)]: Done  86 out of  86 | elapsed:  9.4min remaining:    0.0s
# [CV] alpha=10.0, loss=log, penalty=l2 ................................
# [CV]  alpha=10.0, loss=log, penalty=l2, score=0.7361697366112729, total=   5.4s
# [Parallel(n_jobs=1)]: Done  87 out of  87 | elapsed:  9.4min remaining:    0.0s
# [CV] alpha=10.0, loss=log, penalty=l2 ................................
# [CV]  alpha=10.0, loss=log, penalty=l2, score=0.7306502540618938, total=   5.8s
# [Parallel(n_jobs=1)]: Done  88 out of  88 | elapsed:  9.5min remaining:    0.0s
# [CV] alpha=10.0, loss=log, penalty=l2 ................................
# [CV]  alpha=10.0, loss=log, penalty=l2, score=0.734748332335582, total=   5.4s
# [Parallel(n_jobs=1)]: Done  89 out of  89 | elapsed:  9.6min remaining:    0.0s
# [CV] alpha=10.0, loss=log, penalty=l2 ................................
# [CV]  alpha=10.0, loss=log, penalty=l2, score=0.7401017266433423, total=   5.3s
# [Parallel(n_jobs=1)]: Done  90 out of  90 | elapsed:  9.7min remaining:    0.0s
# [CV] alpha=10.0, loss=modified_huber, penalty=l1 .....................
# [CV]  alpha=10.0, loss=modified_huber, penalty=l1, score=0.5, total=   5.7s
# [Parallel(n_jobs=1)]: Done  91 out of  91 | elapsed:  9.8min remaining:    0.0s
# [CV] alpha=10.0, loss=modified_huber, penalty=l1 .....................
# [CV]  alpha=10.0, loss=modified_huber, penalty=l1, score=0.5, total=   8.0s
# [Parallel(n_jobs=1)]: Done  92 out of  92 | elapsed: 10.0min remaining:    0.0s
# [CV] alpha=10.0, loss=modified_huber, penalty=l1 .....................
# [CV]  alpha=10.0, loss=modified_huber, penalty=l1, score=0.5, total=   7.5s
# [Parallel(n_jobs=1)]: Done  93 out of  93 | elapsed: 10.1min remaining:    0.0s
# [CV] alpha=10.0, loss=modified_huber, penalty=l1 .....................
# [CV]  alpha=10.0, loss=modified_huber, penalty=l1, score=0.5, total=   8.2s
# [Parallel(n_jobs=1)]: Done  94 out of  94 | elapsed: 10.2min remaining:    0.0s
# [CV] alpha=10.0, loss=modified_huber, penalty=l1 .....................
# [CV]  alpha=10.0, loss=modified_huber, penalty=l1, score=0.5, total=   8.0s
# [Parallel(n_jobs=1)]: Done  95 out of  95 | elapsed: 10.4min remaining:    0.0s
# [CV] alpha=10.0, loss=modified_huber, penalty=l2 .....................
# [CV]  alpha=10.0, loss=modified_huber, penalty=l2, score=0.7345887767843367, total=   4.6s
# [Parallel(n_jobs=1)]: Done  96 out of  96 | elapsed: 10.5min remaining:    0.0s
# [CV] alpha=10.0, loss=modified_huber, penalty=l2 .....................
# [CV]  alpha=10.0, loss=modified_huber, penalty=l2, score=0.7320791964680652, total=   4.7s
# [Parallel(n_jobs=1)]: Done  97 out of  97 | elapsed: 10.5min remaining:    0.0s
# [CV] alpha=10.0, loss=modified_huber, penalty=l2 .....................
# [CV]  alpha=10.0, loss=modified_huber, penalty=l2, score=0.7397072358981164, total=   5.0s
# [Parallel(n_jobs=1)]: Done  98 out of  98 | elapsed: 10.6min remaining:    0.0s
# [CV] alpha=10.0, loss=modified_huber, penalty=l2 .....................
# [CV]  alpha=10.0, loss=modified_huber, penalty=l2, score=0.7541091405514173, total=   5.7s
# [Parallel(n_jobs=1)]: Done  99 out of  99 | elapsed: 10.7min remaining:    0.0s
# [CV] alpha=10.0, loss=modified_huber, penalty=l2 .....................
# [CV]  alpha=10.0, loss=modified_huber, penalty=l2, score=0.756445843439763, total=   5.6s
# [CV] alpha=100.0, loss=log, penalty=l1 ...............................
# [CV] ..... alpha=100.0, loss=log, penalty=l1, score=0.5, total=   7.8s
# [CV] alpha=100.0, loss=log, penalty=l1 ...............................
# [CV] ..... alpha=100.0, loss=log, penalty=l1, score=0.5, total=   7.7s
# [CV] alpha=100.0, loss=log, penalty=l1 ...............................
# [CV] ..... alpha=100.0, loss=log, penalty=l1, score=0.5, total=   7.6s
# [CV] alpha=100.0, loss=log, penalty=l1 ...............................
# [CV] ..... alpha=100.0, loss=log, penalty=l1, score=0.5, total=   7.9s
# [CV] alpha=100.0, loss=log, penalty=l1 ...............................
# [CV] ..... alpha=100.0, loss=log, penalty=l1, score=0.5, total=   7.8s
# [CV] alpha=100.0, loss=log, penalty=l2 ...............................
# [CV]  alpha=100.0, loss=log, penalty=l2, score=0.7311219606971822, total=   5.9s
# [CV] alpha=100.0, loss=log, penalty=l2 ...............................
# [CV]  alpha=100.0, loss=log, penalty=l2, score=0.7305747409466776, total=   5.4s
# [CV] alpha=100.0, loss=log, penalty=l2 ...............................
# [CV]  alpha=100.0, loss=log, penalty=l2, score=0.7251673542449837, total=   5.4s
# [CV] alpha=100.0, loss=log, penalty=l2 ...............................
# [CV]  alpha=100.0, loss=log, penalty=l2, score=0.7273903189991828, total=   6.0s
# [CV] alpha=100.0, loss=log, penalty=l2 ...............................
# [CV]  alpha=100.0, loss=log, penalty=l2, score=0.7338612233384724, total=   5.3s
# [CV] alpha=100.0, loss=modified_huber, penalty=l1 ....................
# [CV]  alpha=100.0, loss=modified_huber, penalty=l1, score=0.5, total=   7.8s
# [CV] alpha=100.0, loss=modified_huber, penalty=l1 ....................
# [CV]  alpha=100.0, loss=modified_huber, penalty=l1, score=0.5, total=   8.2s
# [CV] alpha=100.0, loss=modified_huber, penalty=l1 ....................
# [CV]  alpha=100.0, loss=modified_huber, penalty=l1, score=0.5, total=   7.4s
# [CV] alpha=100.0, loss=modified_huber, penalty=l1 ....................
# [CV]  alpha=100.0, loss=modified_huber, penalty=l1, score=0.5, total=   7.6s
# [CV] alpha=100.0, loss=modified_huber, penalty=l1 ....................
# [CV]  alpha=100.0, loss=modified_huber, penalty=l1, score=0.5, total=   7.8s
# [CV] alpha=100.0, loss=modified_huber, penalty=l2 ....................
# [CV]  alpha=100.0, loss=modified_huber, penalty=l2, score=0.7351508776797162, total=   5.7s
# [CV] alpha=100.0, loss=modified_huber, penalty=l2 ....................
# [CV]  alpha=100.0, loss=modified_huber, penalty=l2, score=0.7360241573569776, total=   5.0s
# [CV] alpha=100.0, loss=modified_huber, penalty=l2 ....................
# [CV]  alpha=100.0, loss=modified_huber, penalty=l2, score=0.7298907446666525, total=   5.0s
# [CV] alpha=100.0, loss=modified_huber, penalty=l2 ....................
# [CV]  alpha=100.0, loss=modified_huber, penalty=l2, score=0.7313609223565258, total=   5.3s
# [CV] alpha=100.0, loss=modified_huber, penalty=l2 ....................
# [CV]  alpha=100.0, loss=modified_huber, penalty=l2, score=0.7386285137515931, total=   5.2s
# [Parallel(n_jobs=1)]: Done 120 out of 120 | elapsed: 13.1min finished
# {'alpha': 0.01, 'loss': 'log', 'penalty': 'l2'}
# ------------
# 0.7268778258398895 {'alpha': 0.001, 'loss': 'log', 'penalty': 'l1'}
# 0.7547986120032248 {'alpha': 0.001, 'loss': 'log', 'penalty': 'l2'}
# 0.7309294528260162 {'alpha': 0.001, 'loss': 'modified_huber', 'penalty': 'l1'}
# 0.6834547224347632 {'alpha': 0.001, 'loss': 'modified_huber', 'penalty': 'l2'}
# 0.7038416153918897 {'alpha': 0.01, 'loss': 'log', 'penalty': 'l1'}
# 0.76066893524124 {'alpha': 0.01, 'loss': 'log', 'penalty': 'l2'}
# 0.7024775449998284 {'alpha': 0.01, 'loss': 'modified_huber', 'penalty': 'l1'}
# 0.758983584392025 {'alpha': 0.01, 'loss': 'modified_huber', 'penalty': 'l2'}
# 0.49804742707771205 {'alpha': 0.1, 'loss': 'log', 'penalty': 'l1'}
# 0.7566218499158425 {'alpha': 0.1, 'loss': 'log', 'penalty': 'l2'}
# 0.6508198403796825 {'alpha': 0.1, 'loss': 'modified_huber', 'penalty': 'l1'}
# 0.7521519028449424 {'alpha': 0.1, 'loss': 'modified_huber', 'penalty': 'l2'}
# 0.5 {'alpha': 1.0, 'loss': 'log', 'penalty': 'l1'}
# 0.7470602232990375 {'alpha': 1.0, 'loss': 'log', 'penalty': 'l2'}
# 0.4916749082742536 {'alpha': 1.0, 'loss': 'modified_huber', 'penalty': 'l1'}
# 0.7461672797420403 {'alpha': 1.0, 'loss': 'modified_huber', 'penalty': 'l2'}
# 0.5 {'alpha': 10.0, 'loss': 'log', 'penalty': 'l1'}
# 0.7355625535241618 {'alpha': 10.0, 'loss': 'log', 'penalty': 'l2'}
# 0.5 {'alpha': 10.0, 'loss': 'modified_huber', 'penalty': 'l1'}
# 0.7433860100203815 {'alpha': 10.0, 'loss': 'modified_huber', 'penalty': 'l2'}
# 0.5 {'alpha': 100.0, 'loss': 'log', 'penalty': 'l1'}
# 0.7296231245194053 {'alpha': 100.0, 'loss': 'log', 'penalty': 'l2'}
# 0.5 {'alpha': 100.0, 'loss': 'modified_huber', 'penalty': 'l1'}
# 0.734211046218556 {'alpha': 100.0, 'loss': 'modified_huber', 'penalty': 'l2'}

# %%
from sklearn.model_selection import cross_val_predict

sgd_final_clf = grid_search_sgd_cv.best_estimator_
y_probas_sgd_final = cross_val_predict(sgd_final_clf, X_tr, y_train, cv=3, method="predict_proba")
y_scores_sgd_final = y_probas_sgd_final[:, 1] 
fpr_sgd_final, tpr_sgd_final, thresholds_sgd_final = roc_curve(y_train, y_scores_sgd_final)

print ("AUC: ", auc(fpr_sgd_final, tpr_sgd_final))
# Out:
# AUC:  0.7497403082624194

# %%
predictions = grid_search_sgd_cv.predict_proba(X_te)[:, 1]
submit = load_credit_data ("submit_labels.csv")
submit['TARGET'] = predictions
submit.to_csv('sgd_features_final.csv', index = False)

# %% [markdown]
# ### DecisionTree

# %%
from sklearn.tree import DecisionTreeClassifier

model_tree = DecisionTreeClassifier(random_state=123)

param_grid = {'max_depth' : [None, 1, 3, 5], 'criterion': ['gini', 'entropy']}
grid_search_tree = GridSearchCV(model_tree, param_grid, verbose=100, cv=5, scoring='roc_auc')

grid_search_tree.fit(training_df, y_train)

# Results of the grid search for best n_estimator
print(grid_search_tree.best_params_)
print ("------------")

# Results of the grid search in general
cvres = grid_search_tree.cv_results_
for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]):
    print(mean_score, params)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [CV] criterion=gini, max_depth=None ..................................
# [CV]  criterion=gini, max_depth=None, score=0.5427444942785854, total= 2.2min
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  2.2min remaining:    0.0s
# [CV] criterion=gini, max_depth=None ..................................
# [CV]  criterion=gini, max_depth=None, score=0.5478759723177477, total= 2.3min
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:  4.5min remaining:    0.0s
# [CV] criterion=gini, max_depth=None ..................................
# [CV]  criterion=gini, max_depth=None, score=0.5442868265060261, total= 2.2min
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:  6.7min remaining:    0.0s
# [CV] criterion=gini, max_depth=None ..................................
# [CV]  criterion=gini, max_depth=None, score=0.5450702149601574, total= 2.2min
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:  9.0min remaining:    0.0s
# [CV] criterion=gini, max_depth=None ..................................
# [CV]  criterion=gini, max_depth=None, score=0.5457919802663429, total= 2.2min
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed: 11.2min remaining:    0.0s
# [CV] criterion=gini, max_depth=1 .....................................
# [CV]  criterion=gini, max_depth=1, score=0.6487201560237165, total=   4.8s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed: 11.3min remaining:    0.0s
# [CV] criterion=gini, max_depth=1 .....................................
# [CV]  criterion=gini, max_depth=1, score=0.6502695603041622, total=   4.8s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed: 11.4min remaining:    0.0s
# [CV] criterion=gini, max_depth=1 .....................................
# [CV]  criterion=gini, max_depth=1, score=0.6430852784319463, total=   4.8s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed: 11.5min remaining:    0.0s
# [CV] criterion=gini, max_depth=1 .....................................
# [CV]  criterion=gini, max_depth=1, score=0.6521022166218234, total=   4.7s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed: 11.6min remaining:    0.0s
# [CV] criterion=gini, max_depth=1 .....................................
# [CV]  criterion=gini, max_depth=1, score=0.6477054345841767, total=   4.7s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed: 11.7min remaining:    0.0s
# [CV] criterion=gini, max_depth=3 .....................................
# [CV]  criterion=gini, max_depth=3, score=0.7102469809092384, total=  10.6s
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed: 11.9min remaining:    0.0s
# [CV] criterion=gini, max_depth=3 .....................................
# [CV]  criterion=gini, max_depth=3, score=0.7103159280002378, total=  10.9s
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed: 12.1min remaining:    0.0s
# [CV] criterion=gini, max_depth=3 .....................................
# [CV]  criterion=gini, max_depth=3, score=0.7030702919445618, total=  10.6s
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed: 12.3min remaining:    0.0s
# [CV] criterion=gini, max_depth=3 .....................................
# [CV]  criterion=gini, max_depth=3, score=0.7120131544651819, total=  10.7s
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed: 12.5min remaining:    0.0s
# [CV] criterion=gini, max_depth=3 .....................................
# [CV]  criterion=gini, max_depth=3, score=0.716555708129074, total=  10.5s
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed: 12.6min remaining:    0.0s
# [CV] criterion=gini, max_depth=5 .....................................
# [CV]  criterion=gini, max_depth=5, score=0.7213527181693553, total=  16.5s
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed: 12.9min remaining:    0.0s
# [CV] criterion=gini, max_depth=5 .....................................
# [CV]  criterion=gini, max_depth=5, score=0.7208169926275767, total=  16.2s
# [Parallel(n_jobs=1)]: Done  17 out of  17 | elapsed: 13.2min remaining:    0.0s
# [CV] criterion=gini, max_depth=5 .....................................
# [CV]  criterion=gini, max_depth=5, score=0.7142237949460363, total=  16.1s
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed: 13.5min remaining:    0.0s
# [CV] criterion=gini, max_depth=5 .....................................
# [CV]  criterion=gini, max_depth=5, score=0.7251281833972998, total=  16.5s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed: 13.8min remaining:    0.0s
# [CV] criterion=gini, max_depth=5 .....................................
# [CV]  criterion=gini, max_depth=5, score=0.7270929030585555, total=  16.2s
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed: 14.1min remaining:    0.0s
# [CV] criterion=entropy, max_depth=None ...............................
# [CV]  criterion=entropy, max_depth=None, score=0.5456526097625541, total= 1.2min
# [Parallel(n_jobs=1)]: Done  21 out of  21 | elapsed: 15.3min remaining:    0.0s
# [CV] criterion=entropy, max_depth=None ...............................
# [CV]  criterion=entropy, max_depth=None, score=0.5443067940019353, total= 1.2min
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed: 16.5min remaining:    0.0s
# [CV] criterion=entropy, max_depth=None ...............................
# [CV]  criterion=entropy, max_depth=None, score=0.549759694481994, total= 1.2min
# [Parallel(n_jobs=1)]: Done  23 out of  23 | elapsed: 17.7min remaining:    0.0s
# [CV] criterion=entropy, max_depth=None ...............................
# [CV]  criterion=entropy, max_depth=None, score=0.5492998186484691, total= 1.2min
# [Parallel(n_jobs=1)]: Done  24 out of  24 | elapsed: 18.9min remaining:    0.0s
# [CV] criterion=entropy, max_depth=None ...............................
# [CV]  criterion=entropy, max_depth=None, score=0.5452941590657036, total= 1.2min
# [Parallel(n_jobs=1)]: Done  25 out of  25 | elapsed: 20.1min remaining:    0.0s
# [CV] criterion=entropy, max_depth=1 ..................................
# [CV]  criterion=entropy, max_depth=1, score=0.6582434945499318, total=   4.7s
# [Parallel(n_jobs=1)]: Done  26 out of  26 | elapsed: 20.2min remaining:    0.0s
# [CV] criterion=entropy, max_depth=1 ..................................
# [CV]  criterion=entropy, max_depth=1, score=0.6591011053710052, total=   4.7s
# [Parallel(n_jobs=1)]: Done  27 out of  27 | elapsed: 20.3min remaining:    0.0s
# [CV] criterion=entropy, max_depth=1 ..................................
# [CV]  criterion=entropy, max_depth=1, score=0.6492576785041144, total=   4.7s
# [Parallel(n_jobs=1)]: Done  28 out of  28 | elapsed: 20.4min remaining:    0.0s
# [CV] criterion=entropy, max_depth=1 ..................................
# [CV]  criterion=entropy, max_depth=1, score=0.6566932961100735, total=   4.7s
# [Parallel(n_jobs=1)]: Done  29 out of  29 | elapsed: 20.5min remaining:    0.0s
# [CV] criterion=entropy, max_depth=1 ..................................
# [CV]  criterion=entropy, max_depth=1, score=0.6586064209018822, total=   4.7s
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed: 20.6min remaining:    0.0s
# [CV] criterion=entropy, max_depth=3 ..................................
# [CV]  criterion=entropy, max_depth=3, score=0.7109115928660766, total=  11.5s
# [Parallel(n_jobs=1)]: Done  31 out of  31 | elapsed: 20.8min remaining:    0.0s
# [CV] criterion=entropy, max_depth=3 ..................................
# [CV]  criterion=entropy, max_depth=3, score=0.7120004846348159, total=  12.1s
# [Parallel(n_jobs=1)]: Done  32 out of  32 | elapsed: 21.0min remaining:    0.0s
# [CV] criterion=entropy, max_depth=3 ..................................
# [CV]  criterion=entropy, max_depth=3, score=0.704309172645471, total=  11.6s
# [Parallel(n_jobs=1)]: Done  33 out of  33 | elapsed: 21.2min remaining:    0.0s
# [CV] criterion=entropy, max_depth=3 ..................................
# [CV]  criterion=entropy, max_depth=3, score=0.7152425219813007, total=  11.8s
# [Parallel(n_jobs=1)]: Done  34 out of  34 | elapsed: 21.5min remaining:    0.0s
# [CV] criterion=entropy, max_depth=3 ..................................
# [CV]  criterion=entropy, max_depth=3, score=0.714105459478532, total=  11.7s
# [Parallel(n_jobs=1)]: Done  35 out of  35 | elapsed: 21.7min remaining:    0.0s
# [CV] criterion=entropy, max_depth=5 ..................................
# [CV]  criterion=entropy, max_depth=5, score=0.7213701114921789, total=  19.6s
# [Parallel(n_jobs=1)]: Done  36 out of  36 | elapsed: 22.0min remaining:    0.0s
# [CV] criterion=entropy, max_depth=5 ..................................
# [CV]  criterion=entropy, max_depth=5, score=0.7211989720711731, total=  19.2s
# [Parallel(n_jobs=1)]: Done  37 out of  37 | elapsed: 22.3min remaining:    0.0s
# [CV] criterion=entropy, max_depth=5 ..................................
# [CV]  criterion=entropy, max_depth=5, score=0.7164000061915268, total=  19.1s
# [Parallel(n_jobs=1)]: Done  38 out of  38 | elapsed: 22.7min remaining:    0.0s
# [CV] criterion=entropy, max_depth=5 ..................................
# [CV]  criterion=entropy, max_depth=5, score=0.7260463408708759, total=  19.3s
# [Parallel(n_jobs=1)]: Done  39 out of  39 | elapsed: 23.0min remaining:    0.0s
# [CV] criterion=entropy, max_depth=5 ..................................
# [CV]  criterion=entropy, max_depth=5, score=0.7252957286783169, total=  19.2s
# [Parallel(n_jobs=1)]: Done  40 out of  40 | elapsed: 23.3min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  40 out of  40 | elapsed: 23.3min finished
# {'criterion': 'entropy', 'max_depth': 5}
# ------------
# 0.545153889830594 {'criterion': 'gini', 'max_depth': None}
# 0.6483765303106107 {'criterion': 'gini', 'max_depth': 1}
# 0.7104404120606348 {'criterion': 'gini', 'max_depth': 3}
# 0.7217229172359044 {'criterion': 'gini', 'max_depth': 5}
# 0.5468626112572951 {'criterion': 'entropy', 'max_depth': None}
# 0.6563804051460317 {'criterion': 'entropy', 'max_depth': 1}
# 0.7113138450131447 {'criterion': 'entropy', 'max_depth': 3}
# 0.7220622296100969 {'criterion': 'entropy', 'max_depth': 5}

# %%
from sklearn.model_selection import cross_val_predict

tree_final_clf = grid_search_tree.best_estimator_
y_probas_tree_final = cross_val_predict(tree_final_clf, training_df, y_train, cv=3, method="predict_proba")
y_scores_tree_final = y_probas_tree_final[:, 1] 
fpr_tree_final, tpr_tree_final, thresholds_tree_final = roc_curve(y_train, y_scores_tree_final)

print ("AUC: ", auc(fpr_tree_final, tpr_tree_final))
# Out:
# AUC:  0.7238740728693391

# %%
predictions = tree_final_clf.predict_proba(testing_df)[:, 1]
submit = load_credit_data ("submit_labels.csv")
submit['TARGET'] = predictions
submit.to_csv('tree_features_final.csv', index = False)

# %% [markdown]
# ### AdaBoost on DecisionTree

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier

model_ada = AdaBoostClassifier(DecisionTreeClassifier(max_depth=5, criterion='entropy'), random_state=123)

param_distributions = {'learning_rate': [0.2, 0.5, 0.7]}
grid_search_ada_cv = GridSearchCV(model_ada, param_distributions, cv=5, scoring='roc_auc', verbose=100) 

grid_search_ada_cv.fit(training_df, y_train)

# Results of the grid search for best n_estimator
print(grid_search_ada_cv.best_params_)
print ("------------")

# Results of the grid search in general
cvres = grid_search_ada_cv.cv_results_
for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]):
    print(mean_score, params)
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [CV] learning_rate=0.2 ...............................................
# [CV] ...... learning_rate=0.2, score=0.7530576072195488, total=15.6min
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed: 15.7min remaining:    0.0s
# [CV] learning_rate=0.2 ...............................................
# [CV] ...... learning_rate=0.2, score=0.7554646538718301, total=15.4min
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed: 31.1min remaining:    0.0s
# [CV] learning_rate=0.2 ...............................................
# [CV] ...... learning_rate=0.2, score=0.7472669405366369, total=16.4min
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed: 47.6min remaining:    0.0s
# [CV] learning_rate=0.2 ...............................................
# [CV] ...... learning_rate=0.2, score=0.7565723137470367, total=16.8min
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed: 64.5min remaining:    0.0s
# [CV] learning_rate=0.2 ...............................................
# [CV] ...... learning_rate=0.2, score=0.7597848113118839, total=16.8min
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed: 81.4min remaining:    0.0s
# [CV] learning_rate=0.5 ...............................................
# [CV] ........ learning_rate=0.5, score=0.73314500452547, total=16.5min
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed: 98.0min remaining:    0.0s
# [CV] learning_rate=0.5 ...............................................
# [CV] ...... learning_rate=0.5, score=0.7455837536615909, total=16.4min
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed: 114.5min remaining:    0.0s
# [CV] learning_rate=0.5 ...............................................
# [CV] ...... learning_rate=0.5, score=0.7371180697626545, total=16.5min
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed: 131.1min remaining:    0.0s
# [CV] learning_rate=0.5 ...............................................
# [CV] ....... learning_rate=0.5, score=0.742253763147131, total=16.2min
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed: 147.4min remaining:    0.0s
# [CV] learning_rate=0.5 ...............................................
# [CV] ...... learning_rate=0.5, score=0.7439755348479026, total=15.9min
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed: 163.3min remaining:    0.0s
# [CV] learning_rate=0.7 ...............................................
# [CV] ...... learning_rate=0.7, score=0.7280173959589852, total=15.8min
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed: 179.3min remaining:    0.0s
# [CV] learning_rate=0.7 ...............................................
# [CV] ...... learning_rate=0.7, score=0.7380995122640769, total=15.9min
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed: 195.2min remaining:    0.0s
# [CV] learning_rate=0.7 ...............................................
# [CV] ...... learning_rate=0.7, score=0.7308469116313263, total=16.7min
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed: 212.0min remaining:    0.0s
# [CV] learning_rate=0.7 ...............................................
# [CV] ...... learning_rate=0.7, score=0.7331032457939431, total=16.3min
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed: 228.4min remaining:    0.0s
# [CV] learning_rate=0.7 ...............................................
# [CV] ...... learning_rate=0.7, score=0.7396674683411434, total=15.7min
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed: 244.2min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed: 244.2min finished
# {'learning_rate': 0.2}
# ------------
# 0.75442926087687 {'learning_rate': 0.2}
# 0.7404152015468015 {'learning_rate': 0.5}
# 0.7339468875156225 {'learning_rate': 0.7}

# %%
# Find BEST model
from sklearn.model_selection import cross_val_predict

ada_final_clf = grid_search_ada_cv.best_estimator_
y_probas_ada_final = cross_val_predict(ada_final_clf, training_df, y_train, cv=3, method="predict_proba")
y_scores_ada_final = y_probas_ada_final[:, 1] 
fpr_ada_final, tpr_ada_final, thresholds_ada_final = roc_curve(y_train, y_scores_ada_final)

print ("AUC: ", auc(fpr_ada_final, tpr_ada_final))
# Out:
# AUC:  0.7458762836569657

# %%
predictions = ada_final_clf.predict_proba(testing_df)[:, 1]
submit = load_credit_data ("submit_labels.csv")
submit['TARGET'] = predictions
submit.to_csv('ada_features_final_dt.csv', index = False)

# %% [markdown]
# ### Ensembles of 'Best'

# %%
from sklearn.ensemble import VotingClassifier
from sklearn.ensemble import RandomForestClassifier

# To make this notebook's output stable across runs
np.random.seed(123)

b_clf1 = forest_final_clf
b_clf2 = log_final_clf
b_clf3 = tree_final_clf
# b_clf4 = SGDClassifier (alpha=0.1, loss='log', penalty='l2')

b_eclf = VotingClassifier(estimators=[('rfor', b_clf1), ('logreg', b_clf2), ('dt', b_clf3)], weights=[1,1,1], voting='soft')
b_eclf = b_eclf.fit(training_df, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-751d89551ed0> in <module>()
#       6
#       7 b_clf1 = forest_final_clf
# ----> 8 b_clf2 = log_final_clf
#       9 b_clf3 = tree_final_clf
#      10 # b_clf4 = SGDClassifier (alpha=0.1, loss='log', penalty='l2')
#
# NameError: name 'log_final_clf' is not defined

# %%
from sklearn.ensemble import VotingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB

# To make this notebook's output stable across runs
np.random.seed(123)

b_clf1 = RandomForestClassifier(n_estimators=300, max_depth=5)
b_clf2 = LogisticRegression(C=1, penalty='l1')
b_clf3 = DecisionTreeClassifier (max_depth=5, criterion='entropy')
# b_clf4 = SGDClassifier (alpha=0.1, loss='log', penalty='l2')
# b_clf4 = GaussianNB() # NEW
b_eclf = VotingClassifier(estimators=[('rfor', b_clf1), ('logreg', b_clf2), ('dt', b_clf3)], weights=[1,1,1], voting='soft')


b_eclf = b_eclf.fit(training_df, y_train)

# %%
from sklearn.model_selection import cross_val_predict

y_probas_bvote_final = cross_val_predict(b_eclf, training_df, y_train, cv=3, method="predict_proba")
y_scores_bvote_final = y_probas_bvote_final[:, 1] 
fpr_bvote_final, tpr_bvote_final, thresholds_bvote_final = roc_curve(y_train, y_scores_bvote_final)

print ("AUC: ", auc(fpr_bvote_final, tpr_bvote_final))
# Out:
# AUC:  0.7633885663309568

# %%
predictions = b_eclf.predict_proba(testing_df)[:, 1]
submit = load_credit_data ("submit_labels.csv")
submit['TARGET'] = predictions
submit.to_csv('best_voting_classifier_features_final.csv', index = False)

# %% [markdown]
# ### Ensemble of Ensembles

# %%
from sklearn.metrics import roc_auc_score
from sklearn.ensemble import ExtraTreesClassifier, RandomForestClassifier, VotingClassifier, AdaBoostClassifier, GradientBoostingClassifier

# conda install py-xgboost
import xgboost as xgb

# To make this notebook's output stable across runs
np.random.seed(123)

clf1 = AdaBoostClassifier(n_estimators=300)
clf2 = ExtraTreesClassifier(n_estimators=300, max_depth=5)
clf3 = xgb.XGBClassifier(n_estimators=300, max_depth=5)
clf4 = GradientBoostingClassifier(n_estimators=300, max_depth=5)
eclf = VotingClassifier(estimators=[('ab', clf1), ('etc', clf2), ('xgb', clf3),('gbc', clf4)], weights=[1,1,1,1], voting='soft')
eclf = eclf.fit(training_df, y_train)

# %%
from sklearn.model_selection import cross_val_predict

y_probas_vote_final = cross_val_predict(eclf, training_df, y_train, cv=3, method="predict_proba")
y_scores_vote_final = y_probas_vote_final[:, 1] 
fpr_vote_final, tpr_vote_final, thresholds_vote_final = roc_curve(y_train, y_scores_vote_final)

print ("AUC: ", auc(fpr_vote_final, tpr_vote_final))
# Out:
# AUC:  0.784135630893227

# %%
predictions = eclf.predict_proba(testing_df)[:, 1]
submit = load_credit_data ("submit_labels.csv")
submit['TARGET'] = predictions
submit.to_csv('voting_classifier_ensem_features_final.csv', index = False)

# %% [markdown]
# ### Plot  curves

# %%
plt.figure(figsize=(8, 6))
plot_roc_curve(fpr_final_forest, tpr_final_forest, "Random Forest")
plot_roc_curve(fpr_log_final, tpr_log_final, "Log Reg")
plot_roc_curve(fpr_sgd_final, tpr_sgd_final, "SGD")
plot_roc_curve(fpr_gbc_final, tpr_gbc_final, "GBC")
plot_roc_curve(fpr_ada_final, tpr_ada_final, "AdaBoost")
plot_roc_curve(fpr_bvote_final, tpr_bvote_final, "Ensemble - Best")
plot_roc_curve(fpr_vote_final, tpr_vote_final, "Ensemble - Ensemble")
plt.legend(loc="lower right", fontsize=16)
plt.title("Comparing Models")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-c09e6f3cfa3b> in <module>()
#       1 plt.figure(figsize=(8, 6))
# ----> 2 plot_roc_curve(fpr_final_forest, tpr_final_forest, "Random Forest")
#       3 plot_roc_curve(fpr_log_final, tpr_log_final, "Log Reg")
#       4 plot_roc_curve(fpr_sgd_final, tpr_sgd_final, "SGD")
#       5 plot_roc_curve(fpr_gbc_final, tpr_gbc_final, "GBC")
#
# NameError: name 'fpr_final_forest' is not defined

# %% [markdown]
# ### Submission scores:
#
#    1. Random Forest : 0.731
#    2. Logistic Regression : 0.766
#    3. SGD : 0.739
#    4. AdaBoost Decision Tree : 0.739
#        1. Decision Tree only (for comparison): ---
#    5. Ensemble of ensembles (voting=soft) : 0.780
#    6. Ensemble of 'best' (voting=soft) : 0.758
